# %%
pwd
# Out:
# u'/home/riddhisw/Documents/2017/Scripts_Git/v0/TEST_SCRIPTS_v0/GPRP'

# %%
import sys 
sys.path.append('../../../')

# %%
from gpr.GPRP_risk_analysis import GPRPOptimisation as gpropt

# %%
test_case = 24
variation = 4
Sigma_Max= 10.
R_Max = 15.
LKFFBfilepath = '../../DATA_v0_/'
GPRP_savetopath = '../../DATA_v0_/'

# %%
gprpobject = gpropt(test_case, variation, 
                 Sigma_Max, R_Max, 
                 LKFFBfilepath, GPRP_savetopath)
# Out:
# LKFFB: Data Loaded? Yes

# %%
output = gprpobject.make_GPR_PER()
# Out:
#  ../../../gpr/common.py:66: VisibleDeprecationWarning:using a non-integer number instead of an integer will result in an error in the future
#  ../../../gpr/common.py:67: VisibleDeprecationWarning:using a non-integer number instead of an integer will result in an error in the future
# WARNING: reconstraining parameters gp.std_periodic.variance
# WARNING: reconstraining parameters gp.Gaussian_noise.variance
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/transformations.py:109: RuntimeWarning:overflow encountered in expm1
# KeyboardInterrupt caught, calling on_optimization_end() to round things up
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-12782ac0590a> in <module>()
# ----> 1 output = gprpobject.make_GPR_PER()
#
# /home/riddhisw/Documents/2017/Scripts_Git/gpr/GPRP_risk_analysis.pyc in make_GPR_PER(self, mapname, approx_l_0, randdata)
#     154         for idx_d in xrange(self.dataobject.LKFFB_max_it_BR):
#     155
# --> 156             predictions, truth, msmts, opt_params_list, init_params_list = self.one_GPRP_model(training_pts, approx_l_0, randdata)[0:5]
#     157
#     158             truth_ = truth[self.dataobject.Expt.n_train - self.dataobject.Expt.n_testbefore : self.dataobject.Expt.n_train + self.dataobject.Expt.n_predict]
#
# /home/riddhisw/Documents/2017/Scripts_Git/gpr/GPRP_risk_analysis.pyc in one_GPRP_model(self, training_pts, approx_l_0, randdata, messages, optimizer)
#     130
#     131         init_params_list = [sigma_0, R_0, p_0, l_0]
# --> 132         m1 = self.call_GPy_optimise(X, Y, sigma_0, R_0, p_0, l_0, messages=messages, optimizer=optimizer)
#     133         opt_params_list = [m1.std_periodic.variance[0], m1.Gaussian_noise.variance[0], m1.std_periodic.period[0], m1.std_periodic.lengthscale[0]]
#     134
#
# /home/riddhisw/Documents/2017/Scripts_Git/gpr/GPRP_risk_analysis.pyc in call_GPy_optimise(self, X, Y, sigma_0, R_0, p_0, l_0, sigma_bound, R_bound, input_dim, messages, optimizer)
#     111         # optimise GPR model
#     112         #print('Before Optimisation: ', [m1.std_periodic.variance[0], m1.Gaussian_noise.variance[0], m1.std_periodic.period[0], m1.std_periodic.lengthscale[0]])
# --> 113         m1.optimize(optimizer=optimizer, messages=messages) # Defaults to preferred optimiser if optimizer=None, preferred optimiser == lbfgsb
#     114         #print('After Optimisation: ', [m1.std_periodic.variance[0], m1.Gaussian_noise.variance[0], m1.std_periodic.period[0], m1.std_periodic.lengthscale[0]])
#     115
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/core/gp.pyc in optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     563         self.inference_method.on_optimization_start()
#     564         try:
# --> 565             super(GP, self).optimize(optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     566         except KeyboardInterrupt:
#     567             print("KeyboardInterrupt caught, calling on_optimization_end() to round things up")
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/model.pyc in optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     109
#     110         with VerboseOptimization(self, opt, maxiters=max_iters, verbose=messages, ipython_notebook=ipython_notebook, clear_after_finish=clear_after_finish) as vo:
# --> 111             opt.run(start, f_fp=self._objective_grads, f=self._objective, fp=self._grads)
#     112
#     113         self.optimization_runs.append(opt)
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/optimization/optimization.pyc in run(self, x_init, **kwargs)
#      49     def run(self, x_init, **kwargs):
#      50         start = dt.datetime.now()
# ---> 51         self.opt(x_init, **kwargs)
#      52         end = dt.datetime.now()
#      53         self.time = str(end - start)
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/optimization/optimization.pyc in opt(self, x_init, f_fp, f, fp)
#     122             opt_dict['factr'] = self.bfgs_factor
#     123
# --> 124         opt_result = optimize.fmin_l_bfgs_b(f_fp, x_init, maxfun=self.max_iters, maxiter=self.max_iters, **opt_dict)
#     125         self.x_opt = opt_result[0]
#     126         self.f_opt = f_fp(self.x_opt)[0]
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     191
#     192     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 193                            **opts)
#     194     d = {'grad': res['jac'],
#     195          'task': res['message'],
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     326             # until the completion of the current minimization iteration.
#     327             # Overwrite f and g:
# --> 328             f, g = func_and_grad(x)
#     329         elif task_str.startswith(b'NEW_X'):
#     330             # new iteration
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in func_and_grad(x)
#     276     else:
#     277         def func_and_grad(x):
# --> 278             f = fun(x, *args)
#     279             g = jac(x, *args)
#     280             return f, g
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in __call__(self, x, *args)
#      61     def __call__(self, x, *args):
#      62         self.x = numpy.asarray(x).copy()
# ---> 63         fg = self.fun(x, *args)
#      64         self.jac = fg[1]
#      65         return fg[0]
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/model.pyc in _objective_grads(self, x)
#     268     def _objective_grads(self, x):
#     269         try:
# --> 270             self.optimizer_array = x
#     271             obj_f, self.obj_grads = self.objective_function(), self._transform_gradients(self.objective_function_gradients())
#     272             self._fail_count = 0
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/parameterized.pyc in __setattr__(self, name, val)
#     334                 param = self.parameters[pnames.index(name)]
#     335                 param[:] = val; return
# --> 336         return object.__setattr__(self, name, val);
#     337
#     338     #===========================================================================
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/core/parameter_core.pyc in optimizer_array(self, p)
#     116
#     117         self._optimizer_copy_transformed = False
# --> 118         self.trigger_update()
#     119
#     120     def _trigger_params_changed(self, trigger_parent=True):
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/core/updateable.pyc in trigger_update(self, trigger_parent)
#      77             #print "Warning: updates are off, updating the model will do nothing"
#      78             return
# ---> 79         self._trigger_params_changed(trigger_parent)
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/core/parameter_core.pyc in _trigger_params_changed(self, trigger_parent)
#     126         """
#     127         [p._trigger_params_changed(trigger_parent=False) for p in self.parameters if not p.is_fixed]
# --> 128         self.notify_observers(None, None if trigger_parent else -np.inf)
#     129
#     130     def _size_transformed(self):
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/core/observable.pyc in notify_observers(self, which, min_priority)
#      89                 which = self
#      90             if min_priority is None:
# ---> 91                 [callble(self, which=which) for _, _, callble in self.observers]
#      92             else:
#      93                 for p, _, callble in self.observers:
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/core/parameter_core.pyc in _parameters_changed_notification(self, me, which)
#     496         """
#     497         self._optimizer_copy_transformed = False # tells the optimizer array to update on next request
# --> 498         self.parameters_changed()
#     499     def _pass_through_notify_observers(self, me, which=None):
#     500         self.notify_observers(which=which)
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/core/gp.pyc in parameters_changed(self)
#     193         self.posterior, self._log_marginal_likelihood, self.grad_dict = self.inference_method.inference(self.kern, self.X, self.likelihood, self.Y_normalized, self.mean_function, self.Y_metadata)
#     194         self.likelihood.update_gradients(self.grad_dict['dL_dthetaL'])
# --> 195         self.kern.update_gradients_full(self.grad_dict['dL_dK'], self.X)
#     196         if self.mean_function is not None:
#     197             self.mean_function.update_gradients(self.grad_dict['dL_dm'], self.X)
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/kernel_slice_operations.pyc in wrap(self, dL_dK, X, X2)
#     100     def wrap(self, dL_dK, X, X2=None):
#     101         with _Slice_wrap(self, X, X2) as s:
# --> 102             ret = f(self, dL_dK, s.X, s.X2)
#     103         return ret
#     104     return wrap
#
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.pyc in update_gradients_full(self, dL_dK, X, X2)
#     132         exp_dist = np.exp( -0.5* np.sum( np.square(  sin_base / self.lengthscale ), axis = -1 ) )
#     133
# --> 134         dwl = self.variance * (1.0/np.square(self.lengthscale)) * sin_base*np.cos(base) * (base / self.period)
#     135
#     136         dl = self.variance * np.square( sin_base) / np.power( self.lengthscale, 3)
#
# KeyboardInterrupt:
