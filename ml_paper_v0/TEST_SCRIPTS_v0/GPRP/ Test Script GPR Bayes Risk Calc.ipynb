# %% [markdown]
# We re-create numerical artefacts in the implementation of GPR with a periodic kernel for forward prediction.
# We consider a simple truth trajectory given by a deterministic sine curve. Next, we configure the GPRP algorithm and plot predictions.
#
# To get started, I import some python software I will need:

# %%
import sys
sys.path.append('../../../')
from plot_tools.fig_preamble import * # imports numpy, matplotlib, Py2PDF, plot_helper_funcs, plot_figstyle_sheet
import GPy


from gpr.common import get_data, simple_unlearnable_sine
from data_tools.load_raw_cluster_data import LoadExperiment as le
from plot_tools.plot_figstyle_sheet import color_pallete, predmarker, COLOURDICT, STYLEDICT
from analysis_tools.common import sqr_err
# Out:
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/matplotlib/lines.py:1206: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self._markerfacecolor != fc:
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/matplotlib/lines.py:1182: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self._markeredgecolor != ec:

# %% [markdown]
# I also set up filepaths for saving data

# %%
ver=0
datapath = '../../DATA_v'+str(ver)+'_/' #v'+str(ver)+'/DATA_v'+str(ver)+'/'
datafile = 'GPR_BR_calc_2'
test_case=19
variation=5

# %% [markdown]
# Now, let's consider how to configure the GPRP algorithm with limited apriori information about the truth.
# In our application, let $\Delta t$ represent the shortest possible time-spacing in our procedure between two sequential measurements from an experiment, and let $\Delta t N_T$ represent the longest possible time spacing observed in the measurement record.
#
# We use physical arguments to link the periodicity and the lengthscale to the longest and shortest timescales of the observed system during training. In configuring a GPR algorithm, one decides or optimises $\omega_0^{(B)}$. For the physically set paramter, $\Delta t$ in our procedure, a classical analysis suggests that one needs $2 \pi /(\Delta t \omega_0^{(B)})$ for a computational method to resolve Fourier components of true noise to an order $\omega_0^{(B)}$. Further, any changes in the continuous process below $\Delta t$ will not be observed. These reasons lead us to propose the following initial conditions for kernel hyperparameters at the outset of a procedure:, namely:
#
#     - p = N_train
#     - l = 3 * Delta T

# %%
dataobject = le(test_case, variation, 
                skip = 1,
                GPRP_load='No', GPRP_path = './',
                LKFFB_load = 'Yes', LKFFB_path = datapath,
                AKF_load='No', AKF_path = './',
                LSF_load = 'No', LSF_path = './')

n_train = dataobject.Expt.n_train
Delta_T = dataobject.Expt.Delta_T_Sampling
n_predict = dataobject.Expt.n_predict
n_testbefore = dataobject.Expt.n_testbefore
# Out:
# LKFFB: Data Loaded? Yes

# %%
print dataobject.Expt.n_train, dataobject.Expt.Delta_T_Sampling, dataobject.Expt.n_predict, dataobject.Expt.n_testbefore
# Out:
# 2000 0.001 100 50

# %%
# Set initial starting values for L-BFGS-B OPtimiser in GPy
sigma_0 =100.0
R_0 =  100.0
# Set length scale and periodicity initial values for L-BFGS-B OPtimiser in GPy
length_scale_0 = 3.0*Delta_T
period_0 = 2000.0

total_runs = 50

# Calc 1 
# periodicities = ((2000, 2001), (0, 10**3), (10**3, 10**4), (10**4, 10**5), (None, None))

# Calc 2
periodicities = ((0, 2*10**3), (2*10**3, 4*10**3), (4*10**3, 6*10**3), (6*10**3, 8*10**3), (8*10**3, 10**4), (10**4, 10**5), (None, None))
total_opt_params = 4 # total number of Gpy Optimisation params

# %% [markdown]
# We now implement optimised GPRP model but with constrained periodicities

# %%
pred_list= np.zeros((len(periodicities), total_runs, n_predict+n_testbefore))
opt_list = np.zeros((len(periodicities), total_runs, total_opt_params))
truth_list= np.zeros((len(periodicities), total_runs, n_predict+n_testbefore))
failed_runs_list = np.zeros((len(periodicities), total_runs))

# %%
for idx_run in xrange(total_runs): 

    X, Y, TestX, truth, msmts = get_data(dataobject, points=n_train, randomize='y')
  
    for idx_per in xrange(len(periodicities)):        
        
        # Reset
        kernel_per=0
        gauss=0
        exact=0
        m1=0

        
        # Built model
        kernel_per = GPy.kern.StdPeriodic(1, period=period_0, variance=sigma_0, 
                                          lengthscale=length_scale_0)
        gauss = GPy.likelihoods.Gaussian(variance=R_0)
        exact = GPy.inference.latent_function_inference.ExactGaussianInference()
        m1 = GPy.core.GP(X=X, Y=Y, kernel=kernel_per, likelihood=gauss, inference_method=exact)

        
        # Add constraints to all scenarios accept the last one!!        
        if idx_per != len(periodicities)-1: # last condition
            print("Peridocity is constrained...")
            m1.std_periodic.period.constrain_bounded(periodicities[idx_per][0], periodicities[idx_per][1])
            

        print("Optimise GPRP for:", idx_per, idx_run)
        print(m1)
        
        try:
            m1.optimize(optimizer=None, messages=False)
            opt_list[idx_per, idx_run, :] = [m1.std_periodic.period[0], m1.std_periodic.lengthscale[0], m1.std_periodic.variance[0], gauss.variance[0]]
            pred_list[idx_per, idx_run, :] = m1.predict(TestX)[0].flatten()
            print("Optimisation complete!")
            print(m1)

        except:
            opt_list[idx_per, idx_run, :] = np.zeros(4)
            pred_list[idx_per, idx_run, :] = np.zeros(int(TestX.shape[0]))
            failed_runs_list[idx_per, idx_run] = idx_run
            print("Unexpected error:", sys.exc_info()[0])
            print("Failed run", idx_run)

        truth_list[idx_per, idx_run, :] = truth[int(TestX[0]):] # duplications, but downstream code is easier
        
        np.savez(datapath+datafile,
                 truth_list=truth_list, 
                 pred_list=pred_list,
                 opt_list=opt_list, 
                 failed_runs_list=failed_runs_list,
                 periodicities=periodicities,
                 n_train=n_train, n_predict=n_predict, n_testbefore=n_testbefore,
                 sigma_0=sigma_0, R_0=R_0, length_scale_0=length_scale_0, period_0=period_0,
                 Delta_T=Delta_T, total_runs=total_runs, test_case=test_case, variation=variation )
# Out:
#  ../../../gpr/common.py:66: VisibleDeprecationWarning:using a non-integer number instead of an integer will result in an error in the future
#  ../../../gpr/common.py:67: VisibleDeprecationWarning:using a non-integer number instead of an integer will result in an error in the future
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 0)
#
# Name : gp
# Objective : 1697960.89737
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14692.1818362
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    133912.365829  |      +ve      |
#   std_periodic.period       |           2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |  0.0100652370083  |      +ve      |
#   Gaussian_noise.variance   |    107241.690521  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 0)
#
# Name : gp
# Objective : 1697960.89737
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14692.181836
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    133912.366664  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |  0.0100652372815  |       +ve       |
#   Gaussian_noise.variance   |    107241.691131  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 0)
#
# Name : gp
# Objective : 1216160.07755
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  5000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:136: RuntimeWarning:divide by zero encountered in divide
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:136: RuntimeWarning:invalid value encountered in divide
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:149: RuntimeWarning:invalid value encountered in multiply
# Optimisation complete!
#
# Name : gp
# Objective : 15211.24584
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    54464.1482689  |       +ve       |
#   std_periodic.period       |           6000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |  0.0031959063607  |       +ve       |
#   Gaussian_noise.variance   |    44290.4758365  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 0)
#
# Name : gp
# Objective : 1206516.59121
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  7000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14203.0115909
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    1018617.90346  |       +ve       |
#   std_periodic.period       |           6000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |  0.0045736197679  |       +ve       |
#   Gaussian_noise.variance   |    50990.7906876  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 4, 0)
#
# Name : gp
# Objective : 1345257.58744
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |   100.0  |       +ve        |
#   std_periodic.period       |  9000.0  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |   100.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14203.0106829
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |     1018622.65115  |       +ve        |
#   std_periodic.period       |           10000.0  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00274417378402  |       +ve        |
#   Gaussian_noise.variance   |     50990.9751962  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 5, 0)
#
# Name : gp
# Objective : 5971757.86967
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |    100.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |    100.0  |        +ve         |
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:113: RuntimeWarning:overflow encountered in square
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:132: RuntimeWarning:overflow encountered in square
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:134: RuntimeWarning:divide by zero encountered in divide
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:134: RuntimeWarning:invalid value encountered in multiply
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:144: RuntimeWarning:invalid value encountered in multiply
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/transformations.py:106: RuntimeWarning:invalid value encountered in greater
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/transformations.py:111: RuntimeWarning:invalid value encountered in greater
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 0)
# ('Optimise GPRP for:', 6, 0)
#
# Name : gp
# Objective : 1697960.89737
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/transformations.py:109: RuntimeWarning:overflow encountered in expm1
# Optimisation complete!
#
# Name : gp
# Objective : 14679.6735496
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |              value  |  constraints  |  priors
#   std_periodic.variance     |      132377.657563  |      +ve      |
#   std_periodic.period       |      88582.3195115  |      +ve      |
#   std_periodic.lengthscale  |  0.000229737495876  |      +ve      |
#   Gaussian_noise.variance   |      106021.460703  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 1)
#
# Name : gp
# Objective : 1572715.74462
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14215.0424951
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |           value  |  constraints  |  priors
#   std_periodic.variance     |   846416.713884  |      +ve      |
#   std_periodic.period       |          2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |  0.013061307147  |      +ve      |
#   Gaussian_noise.variance   |   52037.9112347  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 1)
#
# Name : gp
# Objective : 1572715.74462
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14215.0424951
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    846416.694978  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |  0.0130613068691  |       +ve       |
#   Gaussian_noise.variance   |    52037.9107849  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 1)
#
# Name : gp
# Objective : 1154596.12845
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  5000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14657.8230072
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints   |  priors
#   std_periodic.variance     |     124282.078648  |       +ve       |
#   std_periodic.period       |            6000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |  0.00335023311882  |       +ve       |
#   Gaussian_noise.variance   |     104029.452026  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 1)
#
# Name : gp
# Objective : 1156416.33919
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  7000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14212.0117999
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints   |  priors
#   std_periodic.variance     |     859761.620291  |       +ve       |
#   std_periodic.period       |            8000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |  0.00329610695206  |       +ve       |
#   Gaussian_noise.variance   |     51891.9867825  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 4, 1)
#
# Name : gp
# Objective : 1285009.8049
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |   100.0  |       +ve        |
#   std_periodic.period       |  9000.0  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |   100.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14656.804576
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |     124426.017554  |       +ve        |
#   std_periodic.period       |     8000.02258641  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00251269627065  |       +ve        |
#   Gaussian_noise.variance   |     103883.965744  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 5, 1)
#
# Name : gp
# Objective : 6428670.23366
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |    100.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |    100.0  |        +ve         |
# Optimisation complete!
#
# Name : gp
# Objective : 14212.0116688
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |              value  |    constraints     |  priors
#   std_periodic.variance     |      859685.600327  |        +ve         |
#   std_periodic.period       |           100000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |  0.000263684377107  |        +ve         |
#   Gaussian_noise.variance   |      51893.4014626  |        +ve         |
# ('Optimise GPRP for:', 6, 1)
#
# Name : gp
# Objective : 1572715.74462
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14212.0116925
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     859753.282636  |      +ve      |
#   std_periodic.period       |     18397.2541036  |      +ve      |
#   std_periodic.lengthscale  |  0.00143330172964  |      +ve      |
#   Gaussian_noise.variance   |      51892.033654  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 2)
#
# Name : gp
# Objective : 1488066.16917
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14693.8934647
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     119272.417433  |      +ve      |
#   std_periodic.period       |            2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |  0.00956034842406  |      +ve      |
#   Gaussian_noise.variance   |     108103.429731  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 2)
#
# Name : gp
# Objective : 1488066.16917
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14693.8934647
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints   |  priors
#   std_periodic.variance     |     119272.417435  |       +ve       |
#   std_periodic.period       |            2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |  0.00956034842411  |       +ve       |
#   Gaussian_noise.variance   |     108103.429733  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 2)
#
# Name : gp
# Objective : 1137717.87378
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  5000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14690.5654216
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints   |  priors
#   std_periodic.variance     |     119523.398842  |       +ve       |
#   std_periodic.period       |            4000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |  0.00477344280258  |       +ve       |
#   Gaussian_noise.variance   |      107592.97824  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 2)
#
# Name : gp
# Objective : 1162596.20337
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  7000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14690.1620153
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints   |  priors
#   std_periodic.variance     |     119582.522847  |       +ve       |
#   std_periodic.period       |     7998.96332303  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |  0.00238714541597  |       +ve       |
#   Gaussian_noise.variance   |     107534.399496  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 4, 2)
#
# Name : gp
# Objective : 1313231.90744
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |   100.0  |       +ve        |
#   std_periodic.period       |  9000.0  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |   100.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14690.2626784
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |      119566.72174  |       +ve        |
#   std_periodic.period       |     8954.96753568  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00213229684865  |       +ve        |
#   Gaussian_noise.variance   |     107548.262142  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 5, 2)
#
# Name : gp
# Objective : 5642562.1528
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |    100.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |    100.0  |        +ve         |
# Optimisation complete!
#
# Name : gp
# Objective : 14606.8661285
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |              value  |    constraints     |  priors
#   std_periodic.variance     |      134397.707822  |        +ve         |
#   std_periodic.period       |           100000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |  0.000191170271468  |        +ve         |
#   Gaussian_noise.variance   |      96401.0429793  |        +ve         |
# ('Optimise GPRP for:', 6, 2)
#
# Name : gp
# Objective : 1488066.16917
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14884.2205635
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    146980.956987  |      +ve      |
#   std_periodic.period       |    1806.37745903  |      +ve      |
#   std_periodic.lengthscale  |  0.0106917479628  |      +ve      |
#   Gaussian_noise.variance   |    133232.661742  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 3)
#
# Name : gp
# Objective : 1427117.52735
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14589.4434128
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |     112924.48968  |      +ve      |
#   std_periodic.period       |           2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |  0.0100482329765  |      +ve      |
#   Gaussian_noise.variance   |    97341.1334887  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 3)
#
# Name : gp
# Objective : 1427117.52735
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14589.4434128
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    112924.489705  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |  0.0100482337528  |       +ve       |
#   Gaussian_noise.variance   |    97341.1335119  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 3)
#
# Name : gp
# Objective : 1062282.72516
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  5000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14590.2024795
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    113049.804774  |       +ve       |
#   std_periodic.period       |           4000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |  0.0050251930514  |       +ve       |
#   Gaussian_noise.variance   |    97428.0724909  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 3)
#
# Name : gp
# Objective : 1065876.36175
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  7000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14156.04071
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    695300.649829  |       +ve       |
#   std_periodic.period       |           6000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |  0.0040826792331  |       +ve       |
#   Gaussian_noise.variance   |    48528.2722371  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 4, 3)
#
# Name : gp
# Objective : 1179120.2844
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |   100.0  |       +ve        |
#   std_periodic.period       |  9000.0  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |   100.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14589.5660475
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |     113140.970261  |       +ve        |
#   std_periodic.period       |     9812.62677484  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00204847343324  |       +ve        |
#   Gaussian_noise.variance   |      97349.429773  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 5, 3)
#
# Name : gp
# Objective : 5746743.25644
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |    100.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |    100.0  |        +ve         |
# Optimisation complete!
#
# Name : gp
# Objective : 14156.0415455
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |              value  |    constraints     |  priors
#   std_periodic.variance     |       695288.85677  |        +ve         |
#   std_periodic.period       |           100000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |  0.000244962175505  |        +ve         |
#   Gaussian_noise.variance   |      48529.0994921  |        +ve         |
# ('Optimise GPRP for:', 6, 3)
#
# Name : gp
# Objective : 1427117.52735
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14156.0402856
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    695270.790847  |      +ve      |
#   std_periodic.period       |    4888.35312003  |      +ve      |
#   std_periodic.lengthscale  |  0.0050110818542  |      +ve      |
#   Gaussian_noise.variance   |    48528.6286912  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 4)
#
# Name : gp
# Objective : 1533023.28974
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14166.6549974
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    838062.919738  |      +ve      |
#   std_periodic.period       |           2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |  0.0130084256088  |      +ve      |
#   Gaussian_noise.variance   |    49227.6368061  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 4)
#
# Name : gp
# Objective : 1533023.28974
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14166.654996
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    837930.568856  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |  0.0130080894324  |       +ve       |
#   Gaussian_noise.variance   |     49229.367603  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 4)
#
# Name : gp
# Objective : 1129086.02553
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  5000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14167.7689429
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints   |  priors
#   std_periodic.variance     |     824885.845043  |       +ve       |
#   std_periodic.period       |            4000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |  0.00637427092897  |       +ve       |
#   Gaussian_noise.variance   |     48889.3259484  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 4)
#
# Name : gp
# Objective : 1132143.26965
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  7000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14167.7695536
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |          value  |   constraints   |  priors
#   std_periodic.variance     |  824790.967022  |       +ve       |
#   std_periodic.period       |         6000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |  0.00424898439  |       +ve       |
#   Gaussian_noise.variance   |  48897.2706339  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 4, 4)
#
# Name : gp
# Objective : 1258628.25127
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |   100.0  |       +ve        |
#   std_periodic.period       |  9000.0  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |   100.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14620.2827674
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |     123590.818023  |       +ve        |
#   std_periodic.period       |     8000.10557937  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00250520470148  |       +ve        |
#   Gaussian_noise.variance   |     99757.6318111  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 5, 4)
#
# Name : gp
# Objective : 5812692.11945
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |    100.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |    100.0  |        +ve         |
# Optimisation complete!
#
# Name : gp
# Objective : 14167.7698377
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |    constraints     |  priors
#   std_periodic.variance     |    824974.864005  |        +ve         |
#   std_periodic.period       |          10000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |  0.0025497989667  |        +ve         |
#   Gaussian_noise.variance   |      48890.45481  |        +ve         |
# ('Optimise GPRP for:', 6, 4)
#
# Name : gp
# Objective : 1533023.28974
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 4)
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 5)
#
# Name : gp
# Objective : 1453933.36333
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14239.5005875
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    738796.177994  |      +ve      |
#   std_periodic.period       |           2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |  0.0119812792976  |      +ve      |
#   Gaussian_noise.variance   |    52528.8810787  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 5)
#
# Name : gp
# Objective : 1453933.36333
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14239.5005875
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    738794.370511  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |  0.0119813281566  |       +ve       |
#   Gaussian_noise.variance   |    52528.9059025  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 5)
#
# Name : gp
# Objective : 1117411.62444
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  5000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14668.272335
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints   |  priors
#   std_periodic.variance     |     117944.994116  |       +ve       |
#   std_periodic.period       |     5555.26184461  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |  0.00344673800754  |       +ve       |
#   Gaussian_noise.variance   |     105028.393657  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 5)
#
# Name : gp
# Objective : 1141386.24992
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  7000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14667.6541324
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints   |  priors
#   std_periodic.variance     |     118040.221167  |       +ve       |
#   std_periodic.period       |      7999.9952959  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |  0.00239350675634  |       +ve       |
#   Gaussian_noise.variance   |     104945.885206  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 4, 5)
#
# Name : gp
# Objective : 1291728.50727
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |   100.0  |       +ve        |
#   std_periodic.period       |  9000.0  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |   100.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14667.5585909
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |     118053.720797  |       +ve        |
#   std_periodic.period       |     8085.42220881  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00236821348289  |       +ve        |
#   Gaussian_noise.variance   |     104932.012746  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 5, 5)
#
# Name : gp
# Objective : 5602043.25312
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |    100.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |    100.0  |        +ve         |
# Optimisation complete!
#
# Name : gp
# Objective : 4567.57768729
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |               value  |    constraints     |  priors
#   std_periodic.variance     |       675017.512529  |        +ve         |
#   std_periodic.period       |             10000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |   1.12423606548e-47  |        +ve         |
#   Gaussian_noise.variance   |  5.56268464627e-309  |        +ve         |
# ('Optimise GPRP for:', 6, 5)
#
# Name : gp
# Objective : 1453933.36333
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14233.6161817
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
# ...
#   Gaussian_noise.variance   |      90266.7147627  |        +ve         |
# ('Optimise GPRP for:', 6, 47)
#
# Name : gp
# Objective : 1564754.09894
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14617.5156965
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |              value  |  constraints  |  priors
#   std_periodic.variance     |      117305.932574  |      +ve      |
#   std_periodic.period       |      293637.201102  |      +ve      |
#   std_periodic.lengthscale  |  7.13462148362e-05  |      +ve      |
#   Gaussian_noise.variance   |       100678.06767  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 48)
#
# Name : gp
# Objective : 1470408.933
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14193.1522884
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    773399.569265  |      +ve      |
#   std_periodic.period       |           2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |  0.0119388713811  |      +ve      |
#   Gaussian_noise.variance   |    49329.1728863  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 48)
#
# Name : gp
# Objective : 1470408.933
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14193.1522926
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    773401.582845  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |  0.0119386347776  |       +ve       |
#   Gaussian_noise.variance   |    49323.5805643  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 48)
#
# Name : gp
# Objective : 1119476.8645
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  5000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14627.3249138
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints   |  priors
#   std_periodic.variance     |     123820.236095  |       +ve       |
#   std_periodic.period       |            6000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |  0.00317876238101  |       +ve       |
#   Gaussian_noise.variance   |     99540.5385101  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 48)
#
# Name : gp
# Objective : 1145259.96003
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  7000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14630.3528058
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints   |  priors
#   std_periodic.variance     |     123357.050104  |       +ve       |
#   std_periodic.period       |     7823.98728151  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |  0.00243725132723  |       +ve       |
#   Gaussian_noise.variance   |      99929.704228  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 4, 48)
#
# Name : gp
# Objective : 1307146.86441
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |   100.0  |       +ve        |
#   std_periodic.period       |  9000.0  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |   100.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14630.3443674
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |     123358.776489  |       +ve        |
#   std_periodic.period       |     9999.99742713  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00190700808861  |       +ve        |
#   Gaussian_noise.variance   |     99929.0473143  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 5, 48)
#
# Name : gp
# Objective : 5768165.46568
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |    100.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |    100.0  |        +ve         |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 48)
# ('Optimise GPRP for:', 6, 48)
#
# Name : gp
# Objective : 1470408.933
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14637.7302313
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     122253.693537  |      +ve      |
#   std_periodic.period       |     15965.7902795  |      +ve      |
#   std_periodic.lengthscale  |  0.00119431795825  |      +ve      |
#   Gaussian_noise.variance   |      100889.42767  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 49)
#
# Name : gp
# Objective : 1761371.89606
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14195.3875591
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    1166275.12527  |      +ve      |
#   std_periodic.period       |           2000.0  |  0.0,2000.0   |
#   std_periodic.lengthscale  |  0.0132679146373  |      +ve      |
#   Gaussian_noise.variance   |    48896.4628648  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 49)
#
# Name : gp
# Objective : 1761371.89606
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14195.3875591
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    1166298.23593  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,4000.0  |
#   std_periodic.lengthscale  |  0.0132681571371  |       +ve       |
#   Gaussian_noise.variance   |    48895.3598635  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 49)
#
# Name : gp
# Objective : 1279363.06702
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  5000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 4470.29502948
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |               value  |   constraints   |  priors
#   std_periodic.variance     |       889750.194889  |       +ve       |
#   std_periodic.period       |              6000.0  |  4000.0,6000.0  |
#   std_periodic.lengthscale  |   9.18343269129e-06  |       +ve       |
#   Gaussian_noise.variance   |  5.56268464627e-309  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 49)
#
# Name : gp
# Objective : 1308306.29694
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |   100.0  |       +ve       |
#   std_periodic.period       |  7000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |   100.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 16550.4992912
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |          value  |   constraints   |  priors
#   std_periodic.variance     |  1259634.36151  |       +ve       |
#   std_periodic.period       |         6000.0  |  6000.0,8000.0  |
#   std_periodic.lengthscale  |  86.2046825476  |       +ve       |
#   Gaussian_noise.variance   |  869675.854977  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 4, 49)
#
# Name : gp
# Objective : 1522955.97937
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |   100.0  |       +ve        |
#   std_periodic.period       |  9000.0  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |   100.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14669.6218104
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |     151216.289321  |       +ve        |
#   std_periodic.period       |     9854.01658424  |  8000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00192744671803  |       +ve        |
#   Gaussian_noise.variance   |     101692.066664  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 5, 49)
#
# Name : gp
# Objective : 7268295.43938
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |    100.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |    100.0  |        +ve         |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 49)
# ('Optimise GPRP for:', 6, 49)
#
# Name : gp
# Objective : 1761371.89606
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |   100.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |   100.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14677.4634177
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     149908.723968  |      +ve      |
#   std_periodic.period       |     16547.4099917  |      +ve      |
#   std_periodic.lengthscale  |  0.00114732338169  |      +ve      |
#   Gaussian_noise.variance   |     102711.178396  |      +ve      |

# %%
forecastng_errors = np.zeros(( len(periodicities), total_runs, n_predict ))
bayes_pred_risk = np.zeros(( len(periodicities), n_predict ))


plt.figure()

for idx_per in xrange(len(periodicities)):
    
    remove_runs = failed_runs_list[idx_per][(failed_runs_list[idx_per]>0)] 
    print("For periodicity index, ", idx_per, ", total no. of failed runs is:", remove_runs.shape[0])
    
    for case in xrange(total_runs):
        
        forecastng_errors[idx_per, case, :] = sqr_err(pred_list[idx_per, case, n_testbefore:], 
                                                      truth_list[idx_per, case, n_testbefore:])
        
    prd_zero = np.mean(np.delete(truth_list[idx_per]**2, 
                                 remove_runs, axis=0), 
                       axis=0)[n_testbefore:]
    
    bayes_pred_risk[idx_per, :] = np.mean(np.delete(forecastng_errors[idx_per, :, :], 
                                                    remove_runs, axis=0),
                                          axis=0) / prd_zero
    
    plt.plot(np.arange(n_predict), bayes_pred_risk[idx_per],'--',  label=str(periodicities[idx_per]))
    
plt.yscale('log')
plt.xscale('log')
plt.legend(loc=1)
plt.show()

np.savez(figdata+figname2+'riskanalysis', 
         bayes_pred_risk=bayes_pred_risk, 
         periodicities=periodicities)
# Out:
# ('For periodicity index, ', 0, ', total no. of failed runs is:', 1)
# ('For periodicity index, ', 1, ', total no. of failed runs is:', 1)
# ('For periodicity index, ', 2, ', total no. of failed runs is:', 0)
# ('For periodicity index, ', 3, ', total no. of failed runs is:', 1)
# ('For periodicity index, ', 4, ', total no. of failed runs is:', 0)
# ('For periodicity index, ', 5, ', total no. of failed runs is:', 12)
# ('For periodicity index, ', 6, ', total no. of failed runs is:', 1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-faacb628d72c> in <module>()
#      30 plt.show()
#      31
# ---> 32 np.savez(figdata+figname2+'riskanalysis',
#      33          bayes_pred_risk=bayes_pred_risk,
#      34          periodicities=periodicities)
#
# NameError: name 'figdata' is not defined

# %%
'''
idx_var:
0 - period of kernel
1 - lengthscale of kernel
2 - process noise variance
4 - msmt noise variance
d
'''
run_ratio = np.zeros((len(periodicities), total_runs, 4))

for idx_var in xrange(4):
    for idx_per in xrange(len(periodicities)):

        remove_runs = failed_runs_list[idx_per][(failed_runs_list[idx_per]>0)]
        length = total_runs-remove_runs.shape[0]
        run_ratio[idx_per, 0:length, idx_var] = np.delete(opt_list[idx_per, :, idx_var], remove_runs, axis=0) / np.delete(opt_list[idx_per, :, 0], remove_runs, axis=0)

np.savez(figdata+figname2+'riskanalysis', 
         bayes_pred_risk=bayes_pred_risk, 
         periodicities=periodicities, 
         run_ratio=run_ratio)

# %%
np.isfinite(run_ratio)

# %%
gs = gridspec.GridSpec(1,3,
                       left=0.15, right=0.985, 
                       top=0.85, bottom=0.1, 
                       wspace=0.5, hspace=0.2)

fig2 = plt.figure(figsize=(cm2inch(8.6),cm2inch(3)))

bins_ = np.logspace(-11, -4, 20)

idx_var=0
for idx_var in [1,2,3]:
    
    vars()['ax_'+str(idx_var)] = fig2.add_subplot(gs[0, idx_var-1])
    
    idx_per=0
    for idx_per in [2, 3, 4]:#xrange(len(periodicities)):
        
        remove_runs = failed_runs_list[idx_per][(failed_runs_list[idx_per]>0)]
        length = total_runs-remove_runs.shape[0]
        cleaned_data = run_ratio[idx_per, 0:length, idx_var][~np.isnan(run_ratio[idx_per, 0:length, idx_var])]
        
        if idx_var > 1:
            bins_ = np.logspace(-2, 5, 20)
            
        vars()['ax_'+str(idx_var)].hist(cleaned_data, bins=bins_, alpha=0.25, label=str(idx_per))
        vars()['ax_'+str(idx_var)].set_xscale('log')
        vars()['ax_'+str(idx_var)].set_yscale('log')

#vars()['ax_'+str(idx_var)].legend(loc=0)
plt.show()

# %%
'''
0 - period of kernel
1 - lengthscale of kernel
2 - process noise variance
4 - msmt noise variance

'''
titles = ['$2 \pi / \omega_0^{(B)}$', '$l$ (Opt)', '$\sigma$ (Opt)', '$R$ (Opt)'  ]

for idx_var in [0, 1, 2, 3]:
    
    gs = gridspec.GridSpec(1, 5,
                           left=0.15, right=0.985, 
                           top=0.85, bottom=0.1, 
                           wspace=0.5, hspace=0.2)

    fig2 = plt.figure(figsize=(cm2inch(30),cm2inch(8)))
    fig2.suptitle(titles[idx_var])

    for idx_per in xrange(len(periodicities)):

        remove_runs = failed_runs_list[idx_per][(failed_runs_list[idx_per]>0)]
        remaining_runs = np.delete(opt_list[idx_per, :, idx_var], remove_runs, axis=0) / np.delete(opt_list[idx_per, :, 0], remove_runs, axis=0)

        ax = fig2.add_subplot(gs[0, idx_per]) 
        
        
        ax.plot(np.arange(remaining_runs.shape[0]), remaining_runs, 'x')
        
        if idx_var ==0:
            ax.axhline(y=n_train, c='r', label='Fourier Res.')
            ax.set_ylim([10**(-3), 10**7])
        
        if idx_var ==1:
            ax.axhline(y=3*Delta_T, c='r', label='$3\Delta t$')
            ax.set_ylim([10**(-8), 10**3])
            
        if idx_var ==3:
            ax.axhline(y=dataobject.LKFFB_msmt_noise_variance**2, c='r', label='$R$')
            ax.set_ylim([10**(-3), 10**7])
        
        if idx_var ==4:   
            ax.set_ylim([10**(-3), 10**7])
        #ax.set_title(str(periodicities[idx_per]))
        #ax.set_xscale('log')
        
        ax.set_yscale('log')      
        ax.set_xlim([0, 50])

    plt.show()
