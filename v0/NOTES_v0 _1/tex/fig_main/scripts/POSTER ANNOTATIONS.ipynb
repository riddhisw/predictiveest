# %%
import matplotlib.pyplot as plt
import sys
import matplotlib
sys.path.append('../../../../')
from plot_tools.fig_preamble import * 

ver=0
datapath = '../../../DATA_v'+str(ver)+'_/' #v'+str(ver)+'/DATA_v'+str(ver)+'/'
savefig = '../svg/poster_2017_07_08_'
figname = 'annotations'


fig = plt.figure(figsize=(cm2inch(40),cm2inch(12)))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.text(0, 1, 'FIG: Decimation', horizontalalignment='left', fontsize=11)
ax.text(0.2, 1, 'Discrete Binary'+"\n"+'Outcomes', horizontalalignment='center', fontsize=11)
ax.text(0.4, 1, 'Filtered Measurement'+"\n"+'Outcomes', horizontalalignment='center', fontsize=11)
ax.text(0.6, 1, r'Projections on $\hat{\sigma}_z$ '+"\n"+'Yield 1 or 0', horizontalalignment='center', 
        fontsize=11)

ax.text(0, 0.8, r'Fig: Spectrum Reconstruction', horizontalalignment='left', 
        fontsize=10)
ax.text(0.2, 0.8, r'Constrain $p > n_T$ for Same Paramters', horizontalalignment='left', 
        fontsize=10)

ax.text(0.0, 0.6, r'FIG: Algo Schematic', horizontalalignment='left', 
        fontsize=10)

ax.text(0.0, 0.4, r'Weight Coefficients  Measurement Noise Process Noise State Propagation Measurement Action Features', horizontalalignment='left', 
        fontsize=10)
ax.text(0.2, 0.6, r'Measurements Predictions Gain Dynamical Model ', horizontalalignment='left', 
        fontsize=10)

ax.text(0.0, 0.3, r'Learned pattern matches training data after shift', horizontalalignment='left', 
        fontsize=10)

ax.text(0.0, 0.2, r'Calc: $n \in [-c_0n_T, n_P ], \quad c_0 < 3$%; 50 trials; 75x $(\sigma^2, R)$', horizontalalignment='left', 
        fontsize=10)
ax.text(0.0, 0.1, r'Low Risk Thres. $=k\sigma^2_\beta, k\approx 3, 10, 10, 30$ for (a)-(d)', horizontalalignment='left', 
        fontsize=10)
fig.savefig(savefig+figname+'.svg', format='svg', dpi=my_dpi)
plt.show()
plt.close()
# Out:
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/matplotlib/lines.py:1206: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self._markerfacecolor != fc:
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/matplotlib/lines.py:1182: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self._markeredgecolor != ec:

# %%
print Fsize
# Out:
# 10
