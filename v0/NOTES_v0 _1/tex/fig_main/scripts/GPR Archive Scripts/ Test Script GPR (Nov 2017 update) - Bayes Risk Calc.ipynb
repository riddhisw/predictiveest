# %% [markdown]
# We re-create numerical artefacts in the implementation of GPR with a periodic kernel for forward prediction.
# We consider a simple truth trajectory given by a deterministic sine curve. Next, we configure the GPRP algorithm and plot predictions.
#
# To get started, I import some python software I will need:

# %%
import sys
sys.path.append('../../../../../')
from plot_tools.fig_preamble import * # imports numpy, matplotlib, Py2PDF, plot_helper_funcs, plot_figstyle_sheet
import GPy


from gpr.common import get_data, simple_unlearnable_sine
from data_tools.load_raw_cluster_data import LoadExperiment as le
from plot_tools.plot_figstyle_sheet import color_pallete, predmarker, COLOURDICT, STYLEDICT
from analysis_tools.common import sqr_err
# Out:
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/matplotlib/lines.py:1206: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self._markerfacecolor != fc:
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/matplotlib/lines.py:1182: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self._markeredgecolor != ec:

# %% [markdown]
# I also set up filepaths for saving data

# %%
ver=0
datapath = '../../../../DATA_v'+str(ver)+'_/' #v'+str(ver)+'/DATA_v'+str(ver)+'/'
savefig2 = '../svg/paper_v0_'
figdata = '../svg/fig_data/paper_v0_'
figname2 = 'GPR_new_BR'

# %% [markdown]
# Now, let's consider how to configure the GPRP algorithm with limited apriori information about the truth.
# In our application, let $\Delta t$ represent the shortest possible time-spacing in our procedure between two sequential measurements from an experiment, and let $\Delta t N_T$ represent the longest possible time spacing observed in the measurement record.
#
# We use physical arguments to link the periodicity and the lengthscale to the longest and shortest timescales of the observed system during training. In configuring a GPR algorithm, one decides or optimises $\omega_0^{(B)}$. For the physically set paramter, $\Delta t$ in our procedure, a classical analysis suggests that one needs $2 \pi /(\Delta t \omega_0^{(B)})$ for a computational method to resolve Fourier components of true noise to an order $\omega_0^{(B)}$. Further, any changes in the continuous process below $\Delta t$ will not be observed. These reasons lead us to propose the following initial conditions for kernel hyperparameters at the outset of a procedure:, namely:
#
#     - p = N_train
#     - l = 3 * Delta T

# %%
# Set experimental parameters
n_train = 2000
Delta_T = 0.001
n_predict = 100
n_testbefore=50

# %%
# Set initial starting values for L-BFGS-B OPtimiser in GPy
sigma_0 = 1.0
R_0 =  1.0

# %%
# Set length scale and periodicity initial values for L-BFGS-B OPtimiser in GPy
length_scale_0 = 3.0*Delta_T
period_0 = 2000.0

# %% [markdown]
# true = 9.0/3.0
# multipler = 7. # must be an integer
# spacing = true / multipler
# steps = (1./ spacing)/ 0.001
# print steps
# print spacing

# %% [markdown]
# print basis
# print true / (1./(2000*0.001)) # integer

# %% [markdown]
# We now implement optimised GPRP model but with constrained periodicities

# %%
10**4
# Out:
# 10000

# %%
total_runs = 50
periodicities = ((2000, 2001), (0, 10**3), (10**3, 10**4), (10**4, 10**5), (None, None))

# %%
pred_list= np.zeros((len(periodicities), total_runs, n_predict+n_testbefore))
opt_list = np.zeros((len(periodicities), total_runs, 4))
truth_list= np.zeros((len(periodicities), total_runs, n_predict+n_testbefore))
failed_runs_list = np.zeros((len(periodicities), total_runs))

# %%
dataobject = le(19, 5, 
                skip = 1,
                GPRP_load='No', GPRP_path = './',
                LKFFB_load = 'Yes', LKFFB_path = datapath,
                AKF_load='No', AKF_path = './',
                LSF_load = 'No', LSF_path = './')
# Out:
# LKFFB: Data Loaded? Yes

# %%
for idx_run in xrange(total_runs): 

    X, Y, TestX, truth, msmts = get_data(dataobject, points=2000, randomize='y')
  
    for idx_per in xrange(len(periodicities)):        
        
        # Reset
        kernel_per=0
        gauss=0
        exact=0
        m1=0

        
        # Built model
        kernel_per = GPy.kern.StdPeriodic(1, period=period_0, variance=sigma_0, 
                                          lengthscale=length_scale_0)
        gauss = GPy.likelihoods.Gaussian(variance=R_0)
        exact = GPy.inference.latent_function_inference.ExactGaussianInference()
        m1 = GPy.core.GP(X=X, Y=Y, kernel=kernel_per, likelihood=gauss, inference_method=exact)

        
        # Add constraints        
        if idx_per != len(periodicities)-1: # last condition
            print("Peridocity is constrained...")
            m1.std_periodic.period.constrain_bounded(periodicities[idx_per][0], periodicities[idx_per][1])
            

        print("Optimise GPRP for:", idx_per, idx_run)
        print(m1)
        
        try:
            m1.optimize(optimizer=None, messages=False)
            opt_list[idx_per, idx_run, :] = [m1.std_periodic.period[0], m1.std_periodic.lengthscale[0], m1.std_periodic.variance[0], gauss.variance[0]]
            pred_list[idx_per, idx_run, :] = m1.predict(TestX)[0].flatten()
            print("Optimisation complete!")
            print(m1)

        except:
            opt_list[idx_per, idx_run, :] = np.zeros(4)
            pred_list[idx_per, idx_run, :] = np.zeros(int(TestX.shape[0]))
            failed_runs_list[idx_per, idx_run] = idx_run
            print("Unexpected error:", sys.exc_info()[0])
            print("Failed run", idx_run)

        truth_list[idx_per, idx_run, :] = truth[int(TestX[0]):]
        
        np.savez(figdata+figname2,
                 truth_list=truth_list, 
                 pred_list=pred_list,
                 opt_list=opt_list, 
                 failed_runs_list=failed_runs_list)
# Out:
#  ../../../../../gpr/common.py:66: VisibleDeprecationWarning:using a non-integer number instead of an integer will result in an error in the future
#  ../../../../../gpr/common.py:67: VisibleDeprecationWarning:using a non-integer number instead of an integer will result in an error in the future
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 0)
#
# Name : gp
# Objective : 154958413.504
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |     1.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |     1.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14242.2469152
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    862783.756191  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |  0.0137623756107  |       +ve       |
#   Gaussian_noise.variance   |    54697.0040797  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 0)
#
# Name : gp
# Objective : 483030137.067
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |  value  |  constraints  |  priors
#   std_periodic.variance     |    1.0  |      +ve      |
#   std_periodic.period       |  500.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.003  |      +ve      |
#   Gaussian_noise.variance   |    1.0  |      +ve      |
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:113: RuntimeWarning:overflow encountered in square
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:132: RuntimeWarning:overflow encountered in square
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:134: RuntimeWarning:divide by zero encountered in divide
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:134: RuntimeWarning:invalid value encountered in multiply
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:136: RuntimeWarning:divide by zero encountered in divide
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:136: RuntimeWarning:invalid value encountered in divide
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:144: RuntimeWarning:invalid value encountered in multiply
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:149: RuntimeWarning:invalid value encountered in multiply
# Optimisation complete!
#
# Name : gp
# Objective : 367722479.278
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    1.00557320301  |      +ve      |
#   std_periodic.period       |    285.594992872  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.0030136602204  |      +ve      |
#   Gaussian_noise.variance   |    1.04651621674  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 0)
#
# Name : gp
# Objective : 154958413.504
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |     1.0  |       +ve        |
#   std_periodic.period       |  2000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |     1.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14713.3610444
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |     114992.359198  |       +ve        |
#   std_periodic.period       |     3170.22478151  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00660007180238  |       +ve        |
#   Gaussian_noise.variance   |     112424.983147  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 0)
#
# Name : gp
# Objective : 560646645.124
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |      1.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |      1.0  |        +ve         |
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:136: RuntimeWarning:overflow encountered in divide
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/transformations.py:106: RuntimeWarning:invalid value encountered in greater
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/transformations.py:111: RuntimeWarning:invalid value encountered in greater
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 0)
# ('Optimise GPRP for:', 4, 0)
#
# Name : gp
# Objective : 154958413.504
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |     1.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |     1.0  |      +ve      |
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/transformations.py:109: RuntimeWarning:overflow encountered in expm1
# Optimisation complete!
#
# Name : gp
# Objective : 14773.6411401
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    118798.714407  |      +ve      |
#   std_periodic.period       |    1959.62750846  |      +ve      |
#   std_periodic.lengthscale  |  0.0106766672119  |      +ve      |
#   Gaussian_noise.variance   |    120207.858363  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 1)
#
# Name : gp
# Objective : 149537098.044
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |     1.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |     1.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14209.712719
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    801688.002021  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |  0.0125808267344  |       +ve       |
#   Gaussian_noise.variance   |    51356.9300222  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 1)
#
# Name : gp
# Objective : 456469021.31
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |  value  |  constraints  |  priors
#   std_periodic.variance     |    1.0  |      +ve      |
#   std_periodic.period       |  500.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.003  |      +ve      |
#   Gaussian_noise.variance   |    1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 15807.2983498
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    141490.390452  |      +ve      |
#   std_periodic.period       |           1000.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.0205206005981  |      +ve      |
#   Gaussian_noise.variance   |    385187.210467  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 1)
#
# Name : gp
# Objective : 149537098.044
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |     1.0  |       +ve        |
#   std_periodic.period       |  2000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |     1.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14209.494799
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints    |  priors
#   std_periodic.variance     |    800414.655781  |       +ve        |
#   std_periodic.period       |    2001.17229284  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |  0.0125676777386  |       +ve        |
#   Gaussian_noise.variance   |    51333.4313906  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 1)
#
# Name : gp
# Objective : 522788068.842
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |      1.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |      1.0  |        +ve         |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 1)
# ('Optimise GPRP for:', 4, 1)
#
# Name : gp
# Objective : 149537098.044
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |     1.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |     1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14701.2040041
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    113004.627417  |      +ve      |
#   std_periodic.period       |    4427.36664388  |      +ve      |
#   std_periodic.lengthscale  |  0.0044199676298  |      +ve      |
#   Gaussian_noise.variance   |    110149.135889  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 2)
#
# Name : gp
# Objective : 139166812.879
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |     1.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |     1.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14221.0946198
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |     678983.72103  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |  0.0120273831828  |       +ve       |
#   Gaussian_noise.variance   |     52220.657356  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 2)
#
# Name : gp
# Objective : 427527553.609
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |  value  |  constraints  |  priors
#   std_periodic.variance     |    1.0  |      +ve      |
#   std_periodic.period       |  500.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.003  |      +ve      |
#   Gaussian_noise.variance   |    1.0  |      +ve      |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 2)
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 2)
#
# Name : gp
# Objective : 139166812.879
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |     1.0  |       +ve        |
#   std_periodic.period       |  2000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |     1.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14221.4621706
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints    |  priors
#   std_periodic.variance     |    678430.719506  |       +ve        |
#   std_periodic.period       |    9981.46300092  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |  0.0024123215061  |       +ve        |
#   Gaussian_noise.variance   |    52185.6469672  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 2)
#
# Name : gp
# Objective : 569301009.963
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |      1.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |      1.0  |        +ve         |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 2)
# ('Optimise GPRP for:', 4, 2)
#
# Name : gp
# Objective : 139166812.879
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |     1.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |     1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14652.4689973
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     108669.643809  |      +ve      |
#   std_periodic.period       |     4761.69134836  |      +ve      |
#   std_periodic.lengthscale  |  0.00404649510353  |      +ve      |
#   Gaussian_noise.variance   |     104398.293302  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 3)
#
# Name : gp
# Objective : 154054217.479
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |     1.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |     1.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14670.4458009
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    116075.565992  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |  0.0103210513816  |       +ve       |
#   Gaussian_noise.variance   |    106977.479793  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 3)
#
# Name : gp
# Objective : 460972105.69
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |  value  |  constraints  |  priors
#   std_periodic.variance     |    1.0  |      +ve      |
#   std_periodic.period       |  500.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.003  |      +ve      |
#   Gaussian_noise.variance   |    1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 16395.8083186
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |          value  |  constraints  |  priors
#   std_periodic.variance     |  131814.327573  |      +ve      |
#   std_periodic.period       |         1000.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  11776.5491574  |      +ve      |
#   Gaussian_noise.variance   |  765165.788971  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 3)
#
# Name : gp
# Objective : 154054217.479
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |     1.0  |       +ve        |
#   std_periodic.period       |  2000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |     1.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14652.0545105
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |      108044.00211  |       +ve        |
#   std_periodic.period       |     2744.58116161  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00744231729455  |       +ve        |
#   Gaussian_noise.variance   |      93445.709143  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 3)
#
# Name : gp
# Objective : 572117135.275
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |      1.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |      1.0  |        +ve         |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 3)
# ('Optimise GPRP for:', 4, 3)
#
# Name : gp
# Objective : 154054217.479
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |     1.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |     1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14165.0580158
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |              value  |  constraints  |  priors
#   std_periodic.variance     |      811511.395882  |      +ve      |
#   std_periodic.period       |      76568.0948253  |      +ve      |
#   std_periodic.lengthscale  |  0.000334784029581  |      +ve      |
#   Gaussian_noise.variance   |      49021.6593052  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 4)
#
# Name : gp
# Objective : 161382327.078
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |     1.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |     1.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14737.1239302
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints   |  priors
#   std_periodic.variance     |      122929.96969  |       +ve       |
#   std_periodic.period       |            2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |  0.00985615258177  |       +ve       |
#   Gaussian_noise.variance   |     113485.763061  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 4)
#
# Name : gp
# Objective : 528751828.446
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |  value  |  constraints  |  priors
#   std_periodic.variance     |    1.0  |      +ve      |
#   std_periodic.period       |  500.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.003  |      +ve      |
#   Gaussian_noise.variance   |    1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 15953.478491
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    492790.576032  |      +ve      |
#   std_periodic.period       |           1000.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.0272551246811  |      +ve      |
#   Gaussian_noise.variance   |    430053.489566  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 4)
#
# Name : gp
# Objective : 161382327.078
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |     1.0  |       +ve        |
#   std_periodic.period       |  2000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |     1.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14187.9847569
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |     1066289.93387  |       +ve        |
#   std_periodic.period       |           10000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00279814312181  |       +ve        |
#   Gaussian_noise.variance   |     50208.7699595  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 4)
#
# Name : gp
# Objective : 664814535.193
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |      1.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |      1.0  |        +ve         |
# Optimisation complete!
#
# Name : gp
# Objective : 14530.3841518
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |              value  |    constraints     |  priors
#   std_periodic.variance     |      158204.061187  |        +ve         |
#   std_periodic.period       |      99770.3878268  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |  0.000198500784922  |        +ve         |
#   Gaussian_noise.variance   |      86913.6527837  |        +ve         |
# ('Optimise GPRP for:', 4, 4)
#
# Name : gp
# Objective : 161382327.078
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |     1.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |     1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14738.5225679
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     122550.471353  |      +ve      |
#   std_periodic.period       |     2331.50522342  |      +ve      |
#   std_periodic.lengthscale  |  0.00844784092213  |      +ve      |
#   Gaussian_noise.variance   |     113686.563575  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 5)
#
# Name : gp
# Objective : 160724931.17
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |     1.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |     1.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 497111.235251
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    250.826873486  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |  0.0117562613068  |       +ve       |
#   Gaussian_noise.variance   |    233.737130576  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 5)
#
# Name : gp
# Objective : 532876729.171
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |  value  |  constraints  |  priors
#   std_periodic.variance     |    1.0  |      +ve      |
#   std_periodic.period       |  500.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.003  |      +ve      |
#   Gaussian_noise.variance   |    1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 2176465.35191
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |           value  |  constraints  |  priors
#   std_periodic.variance     |   126.675785752  |      +ve      |
#   std_periodic.period       |   1.67406172695  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.752879273884  |      +ve      |
#   Gaussian_noise.variance   |   385.710472942  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 5)
#
# Name : gp
# Objective : 160724931.17
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |     1.0  |       +ve        |
#   std_periodic.period       |  2000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |     1.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14670.8986822
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |     121663.663991  |       +ve        |
#   std_periodic.period       |     2043.73215942  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00988024632016  |       +ve        |
#   Gaussian_noise.variance   |     105875.597937  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 5)
#
# Name : gp
# Objective : 679353019.22
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |      1.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |      1.0  |        +ve         |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 5)
# ('Optimise GPRP for:', 4, 5)
#
# Name : gp
# Objective : 160724931.17
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |     1.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |     1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 497075.24118
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |     250.81011802  |      +ve      |
#   std_periodic.period       |    2001.80860238  |      +ve      |
#   std_periodic.lengthscale  |  0.0117439128121  |      +ve      |
#   Gaussian_noise.variance   |    233.720418465  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 6)
#
# Name : gp
# Objective : 142776246.835
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |     1.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |     1.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14086.862003
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    816263.619815  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |  0.0136552897859  |       +ve       |
#   Gaussian_noise.variance   |    46034.2644403  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 6)
#
# Name : gp
# Objective : 476285376.914
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |  value  |  constraints  |  priors
#   std_periodic.variance     |    1.0  |      +ve      |
#   std_periodic.period       |  500.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.003  |      +ve      |
#   Gaussian_noise.variance   |    1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 126084.090017
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |              value  |  constraints  |  priors
#   std_periodic.variance     |      795.206426452  |      +ve      |
#   std_periodic.period       |  2.71796978446e-07  |  0.0,1000.0   |
#   std_periodic.lengthscale  |      96.2721101101  |      +ve      |
#   Gaussian_noise.variance   |       6354.8724512  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 6)
#
# Name : gp
# Objective : 142776246.835
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |     1.0  |       +ve        |
#   std_periodic.period       |  2000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |     1.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14567.5966123
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints    |  priors
#   std_periodic.variance     |    107560.222196  |       +ve        |
#   std_periodic.period       |    1996.08807873  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |  0.0103360280532  |       +ve        |
#   Gaussian_noise.variance   |    94571.0519631  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 6)
#
# Name : gp
# Objective : 565799464.563
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |      1.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |      1.0  |        +ve         |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 6)
# ('Optimise GPRP for:', 4, 6)
#
# Name : gp
# Objective : 142776246.835
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |     1.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |     1.0  |      +ve      |
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:112: RuntimeWarning:overflow encountered in divide
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:113: RuntimeWarning:invalid value encountered in sin
# Optimisation complete!
#
# Name : gp
# Objective : 19713.3794962
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     14056.3703318  |      +ve      |
#   std_periodic.period       |     5672.58475352  |      +ve      |
#   std_periodic.lengthscale  |  0.00210262866218  |      +ve      |
#   Gaussian_noise.variance   |     12772.3711181  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 7)
#
# Name : gp
# Objective : 158568644.408
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |     1.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |     1.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 4733.47162547
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |               value  |   constraints   |  priors
#   std_periodic.variance     |       765739.015698  |       +ve       |
#   std_periodic.period       |              2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |  1.52141413035e-100  |       +ve       |
#   Gaussian_noise.variance   |  5.56268464627e-309  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 7)
#
# Name : gp
# Objective : 551152109.938
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |  value  |  constraints  |  priors
#   std_periodic.variance     |    1.0  |      +ve      |
#   std_periodic.period       |  500.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.003  |      +ve      |
#   Gaussian_noise.variance   |    1.0  |      +ve      |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 7)
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 7)
#
# Name : gp
# Objective : 158568644.408
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |     1.0  |       +ve        |
#   std_periodic.period       |  2000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |     1.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14648.8349955
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |     115963.975124  |       +ve        |
#   std_periodic.period       |           10000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00214020756015  |       +ve        |
#   Gaussian_noise.variance   |     104803.765138  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 7)
#
# Name : gp
# Objective : 584283507.332
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |      1.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |      1.0  |        +ve         |
# Optimisation complete!
#
# Name : gp
# Objective : 14158.5972217
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |    constraints     |  priors
#   std_periodic.variance     |      895544.85632  |        +ve         |
#   std_periodic.period       |           10000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |  0.00284970064624  |        +ve         |
#   Gaussian_noise.variance   |     50102.0009033  |        +ve         |
# ('Optimise GPRP for:', 4, 7)
#
# Name : gp
# Objective : 158568644.408
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |     1.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |     1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14158.5979842
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     894706.628257  |      +ve      |
#   std_periodic.period       |     4695.53971952  |      +ve      |
#   std_periodic.lengthscale  |  0.00606765641128  |      +ve      |
#   Gaussian_noise.variance   |      50103.912211  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 8)
#
# Name : gp
# Objective : 131236796.016
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |     1.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |     1.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14259.6712608
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    514863.195077  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |  0.0101831999061  |       +ve       |
#   Gaussian_noise.variance   |    53195.6435332  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 8)
#
# Name : gp
# Objective : 396404725.133
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |  value  |  constraints  |  priors
#   std_periodic.variance     |    1.0  |      +ve      |
#   std_periodic.period       |  500.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.003  |      +ve      |
#   Gaussian_noise.variance   |    1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 105177261.047
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     1.35232865766  |      +ve      |
#   std_periodic.period       |  1.1497328455e-06  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.00379163130284  |      +ve      |
#   Gaussian_noise.variance   |     4.67295775816  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 8)
#
# Name : gp
# Objective : 131236796.016
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |     1.0  |       +ve        |
#   std_periodic.period       |  2000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |     1.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14670.2112357
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints    |  priors
#   std_periodic.variance     |     104129.42953  |       +ve        |
#   std_periodic.period       |    1892.13026787  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |  0.0108348987516  |       +ve        |
#   Gaussian_noise.variance   |    109142.344207  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 8)
#
# Name : gp
# Objective : 475954703.65
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |      1.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |      1.0  |        +ve         |
# Optimisation complete!
#
# Name : gp
# Objective : 14259.2467946
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |              value  |    constraints     |  priors
#   std_periodic.variance     |      516209.155126  |        +ve         |
#   std_periodic.period       |           100000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |  0.000203508540238  |        +ve         |
#   Gaussian_noise.variance   |      53091.0704761  |        +ve         |
# ('Optimise GPRP for:', 4, 8)
#
# Name : gp
# Objective : 131236796.016
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |     1.0  |      +ve      |
# ...
#   Gaussian_noise.variance   |     1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14656.9640549
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |      138988.43892  |      +ve      |
#   std_periodic.period       |     2213.83707122  |      +ve      |
#   std_periodic.lengthscale  |  0.00934935567174  |      +ve      |
#   Gaussian_noise.variance   |     124033.794636  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 47)
#
# Name : gp
# Objective : 144010097.788
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |     1.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |     1.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14196.8000273
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |     849709.00016  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |  0.0132612330693  |       +ve       |
#   Gaussian_noise.variance   |    51210.7878667  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 47)
#
# Name : gp
# Objective : 501034580.687
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |  value  |  constraints  |  priors
#   std_periodic.variance     |    1.0  |      +ve      |
#   std_periodic.period       |  500.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.003  |      +ve      |
#   Gaussian_noise.variance   |    1.0  |      +ve      |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 47)
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 47)
#
# Name : gp
# Objective : 144010097.788
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |     1.0  |       +ve        |
#   std_periodic.period       |  2000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |     1.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14176.1703431
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |   constraints    |  priors
#   std_periodic.variance     |     836030.359576  |       +ve        |
#   std_periodic.period       |           10000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |  0.00263200140282  |       +ve        |
#   Gaussian_noise.variance   |     49878.9563116  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 47)
#
# Name : gp
# Objective : 584899181.14
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |      1.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |      1.0  |        +ve         |
# Optimisation complete!
#
# Name : gp
# Objective : 14587.1283044
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |              value  |    constraints     |  priors
#   std_periodic.variance     |       122616.99579  |        +ve         |
#   std_periodic.period       |      96917.0906017  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |  0.000199981439465  |        +ve         |
#   Gaussian_noise.variance   |      95482.2003146  |        +ve         |
# ('Optimise GPRP for:', 4, 47)
#
# Name : gp
# Objective : 144010097.788
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |     1.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |     1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 31142.5603831
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     5502.41074406  |      +ve      |
#   std_periodic.period       |     2576.42397275  |      +ve      |
#   std_periodic.lengthscale  |  0.00758104133184  |      +ve      |
#   Gaussian_noise.variance   |     5091.78687264  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 48)
#
# Name : gp
# Objective : 147886319.964
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |     1.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |     1.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14168.4869447
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |           value  |   constraints   |  priors
#   std_periodic.variance     |   767402.574376  |       +ve       |
#   std_periodic.period       |          2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |  0.012364924668  |       +ve       |
#   Gaussian_noise.variance   |   48798.3423293  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 48)
#
# Name : gp
# Objective : 473458738.473
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |  value  |  constraints  |  priors
#   std_periodic.variance     |    1.0  |      +ve      |
#   std_periodic.period       |  500.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.003  |      +ve      |
#   Gaussian_noise.variance   |    1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 166271394.209
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |              value  |  constraints  |  priors
#   std_periodic.variance     |      1.18453481729  |      +ve      |
#   std_periodic.period       |  8.94884530001e-07  |  0.0,1000.0   |
#   std_periodic.lengthscale  |   0.00345913016574  |      +ve      |
#   Gaussian_noise.variance   |      3.19709706297  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 48)
#
# Name : gp
# Objective : 147886319.964
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |     1.0  |       +ve        |
#   std_periodic.period       |  2000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |     1.0  |       +ve        |
# Optimisation complete!
#
# Name : gp
# Objective : 14685.3612667
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints    |  priors
#   std_periodic.variance     |    105094.433763  |       +ve        |
#   std_periodic.period       |          10000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |  0.0019901844945  |       +ve        |
#   Gaussian_noise.variance   |    109232.236208  |       +ve        |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 48)
#
# Name : gp
# Objective : 577231955.362
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |      1.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |      1.0  |        +ve         |
# Optimisation complete!
#
# Name : gp
# Objective : 14135.0568907
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |    constraints     |  priors
#   std_periodic.variance     |     763434.716799  |        +ve         |
#   std_periodic.period       |     10000.1834947  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |  0.00250195746156  |        +ve         |
#   Gaussian_noise.variance   |     47147.5273575  |        +ve         |
# ('Optimise GPRP for:', 4, 48)
#
# Name : gp
# Objective : 147886319.964
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |     1.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |     1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14623.2024138
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     112520.284394  |      +ve      |
#   std_periodic.period       |     16818.4340608  |      +ve      |
#   std_periodic.lengthscale  |  0.00118231377617  |      +ve      |
#   Gaussian_noise.variance   |     101032.766953  |      +ve      |
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 0, 49)
#
# Name : gp
# Objective : 185436903.481
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints   |  priors
#   std_periodic.variance     |     1.0  |       +ve       |
#   std_periodic.period       |  2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve       |
#   Gaussian_noise.variance   |     1.0  |       +ve       |
# Optimisation complete!
#
# Name : gp
# Objective : 14180.1277966
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |   constraints   |  priors
#   std_periodic.variance     |    1179680.19285  |       +ve       |
#   std_periodic.period       |           2000.0  |  2000.0,2001.0  |
#   std_periodic.lengthscale  |  0.0144294280481  |       +ve       |
#   Gaussian_noise.variance   |    49873.6300891  |       +ve       |
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 1, 49)
#
# Name : gp
# Objective : 644817566.676
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |  value  |  constraints  |  priors
#   std_periodic.variance     |    1.0  |      +ve      |
#   std_periodic.period       |  500.0  |  0.0,1000.0   |
#   std_periodic.lengthscale  |  0.003  |      +ve      |
#   Gaussian_noise.variance   |    1.0  |      +ve      |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 49)
# Peridocity is constrained...
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 2, 49)
#
# Name : gp
# Objective : 185436903.481
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |   constraints    |  priors
#   std_periodic.variance     |     1.0  |       +ve        |
#   std_periodic.period       |  2000.0  |  1000.0,10000.0  |
#   std_periodic.lengthscale  |   0.003  |       +ve        |
#   Gaussian_noise.variance   |     1.0  |       +ve        |
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 49)
# Peridocity is constrained...
# Warning: changing parameters to satisfy constraints
# WARNING: reconstraining parameters gp.std_periodic.period
# ('Optimise GPRP for:', 3, 49)
#
# Name : gp
# Objective : 745182025.143
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |    value  |    constraints     |  priors
#   std_periodic.variance     |      1.0  |        +ve         |
#   std_periodic.period       |  55000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |    0.003  |        +ve         |
#   Gaussian_noise.variance   |      1.0  |        +ve         |
# Optimisation complete!
#
# Name : gp
# Objective : 14422.9959055
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |    constraints     |  priors
#   std_periodic.variance     |     211091.647066  |        +ve         |
#   std_periodic.period       |           10000.0  |  10000.0,100000.0  |
#   std_periodic.lengthscale  |  0.00214360071995  |        +ve         |
#   Gaussian_noise.variance   |     75354.6332598  |        +ve         |
# ('Optimise GPRP for:', 4, 49)
#
# Name : gp
# Objective : 185436903.481
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |     1.0  |      +ve      |
#   std_periodic.period       |  2000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.003  |      +ve      |
#   Gaussian_noise.variance   |     1.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14737.0170252
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     172884.735585  |      +ve      |
#   std_periodic.period       |     2363.93676014  |      +ve      |
#   std_periodic.lengthscale  |  0.00929716358165  |      +ve      |
#   Gaussian_noise.variance   |     136745.895756  |      +ve      |

# %%
forecastng_errors = np.zeros(( len(periodicities), total_runs, n_predict ))
bayes_pred_risk = np.zeros(( len(periodicities), n_predict ))




plt.figure()
labels = ['k=0', 'k=70','k=10^2', 'k=10^4', 'k=10^6']


for idx_per in xrange(len(periodicities)-1):
    
    remove_runs = failed_runs_list[idx_per][(failed_runs_list[idx_per]>0)] 
    print("For periodicity index, ", idx_per, ", total no. of failed runs is:", remove_runs.shape[0])
    
    for case in xrange(total_runs):
        
        forecastng_errors[idx_per, case, :] = sqr_err(pred_list[idx_per, case, n_testbefore:], 
                                                      truth_list[idx_per, case, n_testbefore:])
        
    prd_zero = np.mean(np.delete(truth_list[idx_per]**2, 
                                 remove_runs, axis=0), 
                       axis=0)[n_testbefore:]
    
    bayes_pred_risk[idx_per, :] = np.mean(np.delete(forecastng_errors[idx_per, :, :], 
                                                    remove_runs, axis=0),
                                          axis=0) / prd_zero
    
    plt.plot(np.arange(n_predict), bayes_pred_risk[idx_per],'--',  label=str(periodicities[idx_per]))
    
plt.yscale('log')
plt.xscale('log')
plt.legend(loc=1)
plt.show()

np.savez(figdata+figname2+'riskanalysis', 
         bayes_pred_risk=bayes_pred_risk, 
         periodicities=periodicities)
# Out:
# ('For periodicity index, ', 0, ', total no. of failed runs is:', 0)
# ('For periodicity index, ', 1, ', total no. of failed runs is:', 25)
# ('For periodicity index, ', 2, ', total no. of failed runs is:', 4)
# ('For periodicity index, ', 3, ', total no. of failed runs is:', 23)

# %%
'''
idx_var:
0 - period of kernel
1 - lengthscale of kernel
2 - process noise variance
4 - msmt noise variance
d
'''
run_ratio = np.zeros((len(periodicities), total_runs, 4))

for idx_var in xrange(4):
    for idx_per in xrange(len(periodicities)):

        remove_runs = failed_runs_list[idx_per][(failed_runs_list[idx_per]>0)]
        length = total_runs-remove_runs.shape[0]
        run_ratio[idx_per, 0:length, idx_var] = np.delete(opt_list[idx_per, :, idx_var], remove_runs, axis=0) / np.delete(opt_list[idx_per, :, 0], remove_runs, axis=0)

np.savez(figdata+figname2+'riskanalysis', 
         bayes_pred_risk=bayes_pred_risk, 
         periodicities=periodicities, 
         run_ratio=run_ratio)
# Out:
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:28: RuntimeWarning:invalid value encountered in divide

# %%
np.isfinite(run_ratio)
# Out:
# array([[[ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True]],
#
#        [[ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True]],
#
#        [[ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True]],
#
#        [[False, False, False, False],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True]],
#
#        [[ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True]]], dtype=bool)

# %%
gs = gridspec.GridSpec(1,3,
                       left=0.15, right=0.985, 
                       top=0.85, bottom=0.1, 
                       wspace=0.5, hspace=0.2)

fig2 = plt.figure(figsize=(cm2inch(8.6),cm2inch(3)))

bins_ = np.logspace(-11, -4, 20)

idx_var=0
for idx_var in [1,2,3]:
    
    vars()['ax_'+str(idx_var)] = fig2.add_subplot(gs[0, idx_var-1])
    
    idx_per=0
    for idx_per in [2, 3, 4]:#xrange(len(periodicities)):
        
        remove_runs = failed_runs_list[idx_per][(failed_runs_list[idx_per]>0)]
        length = total_runs-remove_runs.shape[0]
        cleaned_data = run_ratio[idx_per, 0:length, idx_var][~np.isnan(run_ratio[idx_per, 0:length, idx_var])]
        
        if idx_var > 1:
            bins_ = np.logspace(-2, 5, 20)
            
        vars()['ax_'+str(idx_var)].hist(cleaned_data, bins=bins_, alpha=0.25, label=str(idx_per))
        vars()['ax_'+str(idx_var)].set_xscale('log')
        vars()['ax_'+str(idx_var)].set_yscale('log')

#vars()['ax_'+str(idx_var)].legend(loc=0)
plt.show()

# %%
'''
0 - period of kernel
1 - lengthscale of kernel
2 - process noise variance
4 - msmt noise variance

'''
titles = ['$2 \pi / \omega_0^{(B)}$', '$l$ (Opt)', '$\sigma$ (Opt)', '$R$ (Opt)'  ]

for idx_var in [0, 1, 2, 3]:
    
    gs = gridspec.GridSpec(1, 5,
                           left=0.15, right=0.985, 
                           top=0.85, bottom=0.1, 
                           wspace=0.5, hspace=0.2)

    fig2 = plt.figure(figsize=(cm2inch(30),cm2inch(8)))
    fig2.suptitle(titles[idx_var])

    for idx_per in xrange(len(periodicities)):

        remove_runs = failed_runs_list[idx_per][(failed_runs_list[idx_per]>0)]
        remaining_runs = np.delete(opt_list[idx_per, :, idx_var], remove_runs, axis=0) / np.delete(opt_list[idx_per, :, 0], remove_runs, axis=0)

        ax = fig2.add_subplot(gs[0, idx_per]) 
        
        
        ax.plot(np.arange(remaining_runs.shape[0]), remaining_runs, 'x')
        
        if idx_var ==0:
            ax.axhline(y=n_train, c='r', label='Fourier Res.')
            ax.set_ylim([10**(-3), 10**7])
        
        if idx_var ==1:
            ax.axhline(y=3*Delta_T, c='r', label='$3\Delta t$')
            ax.set_ylim([10**(-8), 10**3])
            
        if idx_var ==3:
            ax.axhline(y=dataobject.LKFFB_msmt_noise_variance**2, c='r', label='$R$')
            ax.set_ylim([10**(-3), 10**7])
        
        if idx_var ==4:   
            ax.set_ylim([10**(-3), 10**7])
        #ax.set_title(str(periodicities[idx_per]))
        #ax.set_xscale('log')
        
        ax.set_yscale('log')      
        ax.set_xlim([0, 50])

    plt.show()
# Out:
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:23: RuntimeWarning:invalid value encountered in divide
