# %% [markdown]
# We re-create numerical artefacts in the implementation of GPR with a periodic kernel for forward prediction.
# We consider a simple truth trajectory given by a deterministic sine curve. Next, we configure the GPRP algorithm and plot predictions.
#
# To get started, I import some python software I will need:

# %%
import sys
sys.path.append('../../../')
from plot_tools.fig_preamble import * # imports numpy, matplotlib, Py2PDF, plot_helper_funcs, plot_figstyle_sheet
import GPy


from gpr.common import get_data, simple_unlearnable_sine
from data_tools.load_raw_cluster_data import LoadExperiment as le
from plot_tools.plot_figstyle_sheet import color_pallete, predmarker, COLOURDICT, STYLEDICT
from analysis_tools.common import sqr_err
# Out:
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/matplotlib/lines.py:1206: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self._markerfacecolor != fc:
# /home/riddhisw/anaconda2/lib/python2.7/site-packages/matplotlib/lines.py:1182: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self._markeredgecolor != ec:

# %% [markdown]
# I also set up filepaths for saving data

# %%
ver=0
datapath = '../../DATA_v'+str(ver)+'_/' #v'+str(ver)+'/DATA_v'+str(ver)+'/'
datafile = 'GPR_BR_calc_RBF_RQ_MAT32_QPER_PER'
test_case=19
variation=5

# %%
dataobject = le(test_case, variation, 
                skip = 1,
                GPRP_load='No', GPRP_path = './',
                LKFFB_load = 'Yes', LKFFB_path = datapath,
                AKF_load='No', AKF_path = './',
                LSF_load = 'No', LSF_path = './')

n_train = dataobject.Expt.n_train
Delta_T = dataobject.Expt.Delta_T_Sampling
n_predict = dataobject.Expt.n_predict
n_testbefore = dataobject.Expt.n_testbefore
# Out:
# LKFFB: Data Loaded? Yes

# %%
print dataobject.Expt.n_train, dataobject.Expt.Delta_T_Sampling, dataobject.Expt.n_predict, dataobject.Expt.n_testbefore
# Out:
# 2000 0.001 100 50

# %%
msmt_var = 1000

sigma_0=1000.
period_0 =4000
length_scale_0=0.001

rbf_lengthscale=10.
rbf_variance=1000.
mat_variance=100.
rq_variance=1000.

qrbf_lengthscale=20.
qrbf_variance=50.
qper_lengthscale=0.001
qper_variance=50.
qper_period=4000

# %%
# Set initial starting values for L-BFGS-B OPtimiser in GPy
total_runs=50
kernel_name = ['RBF', 'RQ', 'MAT32', 'QPER', 'PER']
total_opt_params = 50 # total number of Gpy Optimisation params

# %% [markdown]
# We now implement optimised GPRP model but with constrained periodicities

# %%
pred_list= np.zeros((len(kernel_name), total_runs, n_predict+n_testbefore))
truth_list= np.zeros((len(kernel_name), total_runs, n_predict+n_testbefore))
failed_runs_list = np.zeros((len(kernel_name), total_runs))
opt_params=[]

# %%
for idx_run in xrange(total_runs): 

    X, Y, TestX, truth, msmts = get_data(dataobject, points=n_train, randomize='y')
  
    for idx_ker in xrange(len(kernel_name)):        
        
        # Reset
        KERNEL=0
        gauss=0
        exact=0
        m1=0

        # Built model
        KERNEL = {'RBF': GPy.kern.RBF(1, 
                                      lengthscale=rbf_lengthscale,
                                      variance=rbf_variance), 
                  'RQ': GPy.kern.RatQuad(1, variance=rq_variance), 
                  'MAT32': GPy.kern.sde_Matern32(1, variance=mat_variance),
                  'QPER': GPy.kern.RBF(1,
                                      lengthscale=qrbf_lengthscale,
                                      variance=qrbf_variance)*GPy.kern.StdPeriodic(1, 
                                                   period=qper_period, 
                                                   lengthscale=qper_lengthscale,
                                                   variance=qper_variance),
                 'PER': GPy.kern.StdPeriodic(1, period=period_0, 
                                              lengthscale=length_scale_0,
                                              variance=sigma_0),}
        
        gauss = GPy.likelihoods.Gaussian(variance=msmt_var)
        exact = GPy.inference.latent_function_inference.ExactGaussianInference()
        
        
        print("Optimise GPR for:", kernel_name[idx_ker], idx_run)
        
        
        try:
            
            m1 = GPy.core.GP(X=X, Y=Y, kernel=KERNEL[kernel_name[idx_ker]], likelihood=gauss, 
                             inference_method=exact)
            print(m1)
            m1.optimize(optimizer=None, messages=False)
            
            pred_list[idx_ker, idx_run, :] = m1.predict(TestX)[0].flatten()
            print("Optimisation complete!") 
            # Cant raise abnormal terminations in LBFGS in Gpy as exceptions - these are incl in analysis
            print(m1)
            #opt_params.append(m1.flattened_parameters)

        except:
            #opt_params.append(np.zeros(6))
            pred_list[idx_ker, idx_run, :] = np.zeros(int(TestX.shape[0]))
            failed_runs_list[idx_ker, idx_run] = idx_run
            print("Unexpected error:", sys.exc_info()[0])
            print("Failed run", idx_run)

        truth_list[idx_ker, idx_run, :] = truth[int(TestX[0]):] # duplications, but downstream code is easier
        
        
        np.savez(datapath+datafile,
                 truth_list=truth_list, 
                 pred_list=pred_list,
                 #opt_params=opt_params, # too big to save. don't know why!
                 failed_runs_list=failed_runs_list,
                 kernel_name=kernel_name,
                 n_train=n_train, n_predict=n_predict, n_testbefore=n_testbefore,
                 msmt_var=msmt_var, 
                 Delta_T=Delta_T, total_runs=total_runs, test_case=test_case, variation=variation )
# Out:
# ('Optimise GPR for:', 'RBF', 0)
#  ../../../gpr/common.py:66: VisibleDeprecationWarning:using a non-integer number instead of an integer will result in an error in the future
#  ../../../gpr/common.py:67: VisibleDeprecationWarning:using a non-integer number instead of an integer will result in an error in the future
# Name : gp
# Objective : 144354.787223
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   rbf.variance             |  1000.0  |      +ve      |
#   rbf.lengthscale          |    10.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/transformations.py:109: RuntimeWarning:overflow encountered in expm1
# Optimisation complete!
#
# Name : gp
# Objective : 14189.0475676
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   rbf.variance             |  722526.442019  |      +ve      |
#   rbf.lengthscale          |  8.20017743891  |      +ve      |
#   Gaussian_noise.variance  |  51324.5182267  |      +ve      |
# ('Optimise GPR for:', 'RQ', 0)
#
# Name : gp
# Objective : 185026.888032
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   RatQuad.variance         |  1000.0  |      +ve      |
#   RatQuad.lengthscale      |     1.0  |      +ve      |
#   RatQuad.power            |     2.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14189.0483933
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   RatQuad.variance         |  722543.404186  |      +ve      |
#   RatQuad.lengthscale      |  1438.00323975  |      +ve      |
#   RatQuad.power            |  30752.0836292  |      +ve      |
#   Gaussian_noise.variance  |  51324.5117584  |      +ve      |
# ('Optimise GPR for:', 'MAT32', 0)
#
# Name : gp
# Objective : 505647.435221
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   Mat32.variance           |   100.0  |      +ve      |
#   Mat32.lengthscale        |     1.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# KeyboardInterrupt caught, calling on_optimization_end() to round things up
# ('Unexpected error:', <type 'exceptions.KeyboardInterrupt'>)
# ('Failed run', 0)
# ('Optimise GPR for:', 'QPER', 0)
#
# Name : gp
# Objective : 89326.6480643
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |   value  |  constraints  |  priors
#   mul.rbf.variance              |    50.0  |      +ve      |
#   mul.rbf.lengthscale           |    20.0  |      +ve      |
#   mul.std_periodic.variance     |    50.0  |      +ve      |
#   mul.std_periodic.period       |  4000.0  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance       |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4281.38253543
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |               value  |  constraints  |  priors
#   mul.rbf.variance              |       805.409375467  |      +ve      |
#   mul.rbf.lengthscale           |       18.9920753713  |      +ve      |
#   mul.std_periodic.variance     |       794.137231794  |      +ve      |
#   mul.std_periodic.period       |       3999.99601081  |      +ve      |
#   mul.std_periodic.lengthscale  |   2.34544446959e-10  |      +ve      |
#   Gaussian_noise.variance       |  5.70134995643e-288  |      +ve      |
# ('Optimise GPR for:', 'PER', 0)
#
# Name : gp
# Objective : 163758.187284
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14610.5397559
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |      105170.03219  |      +ve      |
#   std_periodic.period       |     4000.05157627  |      +ve      |
#   std_periodic.lengthscale  |  0.00487557823163  |      +ve      |
#   Gaussian_noise.variance   |     100288.581878  |      +ve      |
# ('Optimise GPR for:', 'RBF', 1)
#
# Name : gp
# Objective : 147199.219164
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   rbf.variance             |  1000.0  |      +ve      |
#   rbf.lengthscale          |    10.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14205.1032612
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   rbf.variance             |  799846.450042  |      +ve      |
#   rbf.lengthscale          |  8.36356292998  |      +ve      |
#   Gaussian_noise.variance  |  51888.4856223  |      +ve      |
# ('Optimise GPR for:', 'RQ', 1)
#
# Name : gp
# Objective : 217354.110973
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   RatQuad.variance         |  1000.0  |      +ve      |
#   RatQuad.lengthscale      |     1.0  |      +ve      |
#   RatQuad.power            |     2.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/stationary.py:160: RuntimeWarning:overflow encountered in divide
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/stationary.py:570: RuntimeWarning:overflow encountered in square
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/stationary.py:575: RuntimeWarning:overflow encountered in square
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/stationary.py:577: RuntimeWarning:overflow encountered in multiply
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/stationary.py:577: RuntimeWarning:invalid value encountered in multiply
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/stationary.py:582: RuntimeWarning:overflow encountered in square
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/stationary.py:584: RuntimeWarning:invalid value encountered in multiply
# Optimisation complete!
#
# Name : gp
# Objective : 24071.3626501
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   RatQuad.variance         |  9155.44700003  |      +ve      |
#   RatQuad.lengthscale      |  347.848592724  |      +ve      |
#   RatQuad.power            |  2425.63960863  |      +ve      |
#   Gaussian_noise.variance  |  8177.52869838  |      +ve      |
# ('Optimise GPR for:', 'MAT32', 1)
#
# Name : gp
# Objective : 580240.948448
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   Mat32.variance           |   100.0  |      +ve      |
#   Mat32.lengthscale        |     1.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4874.43898475
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |               value  |  constraints  |  priors
#   Mat32.variance           |       885392.301662  |      +ve      |
#   Mat32.lengthscale        |     0.0116395311741  |      +ve      |
#   Gaussian_noise.variance  |  5.56268464627e-309  |      +ve      |
# ('Optimise GPR for:', 'QPER', 1)
#
# Name : gp
# Objective : 102114.520089
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |   value  |  constraints  |  priors
#   mul.rbf.variance              |    50.0  |      +ve      |
#   mul.rbf.lengthscale           |    20.0  |      +ve      |
#   mul.std_periodic.variance     |    50.0  |      +ve      |
#   mul.std_periodic.period       |  4000.0  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance       |  1000.0  |      +ve      |
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/rbf.py:35: RuntimeWarning:overflow encountered in square
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/rbf.py:38: RuntimeWarning:invalid value encountered in multiply
# Optimisation complete!
#
# Name : gp
# Objective : 5037.15454897
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |               value  |  constraints  |  priors
#   mul.rbf.variance              |       1313.21323735  |      +ve      |
#   mul.rbf.lengthscale           |       145.971440121  |      +ve      |
#   mul.std_periodic.variance     |       1314.15257953  |      +ve      |
#   mul.std_periodic.period       |       3999.96630943  |      +ve      |
#   mul.std_periodic.lengthscale  |   3.22723390329e-75  |      +ve      |
#   Gaussian_noise.variance       |  1.10970464424e-294  |      +ve      |
# ('Optimise GPR for:', 'PER', 1)
#
# Name : gp
# Objective : 189162.2081
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14645.3882066
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |      118176.91662  |      +ve      |
#   std_periodic.period       |     4000.12119895  |      +ve      |
#   std_periodic.lengthscale  |  0.00512832456941  |      +ve      |
#   Gaussian_noise.variance   |     103573.653205  |      +ve      |
# ('Optimise GPR for:', 'RBF', 2)
#
# Name : gp
# Objective : 148314.576555
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   rbf.variance             |  1000.0  |      +ve      |
#   rbf.lengthscale          |    10.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4454.80076756
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |               value  |  constraints  |  priors
#   rbf.variance             |       695326.756688  |      +ve      |
#   rbf.lengthscale          |   9.35141558297e-33  |      +ve      |
#   Gaussian_noise.variance  |  5.56268464627e-309  |      +ve      |
# ('Optimise GPR for:', 'RQ', 2)
#
# Name : gp
# Objective : 204835.972658
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   RatQuad.variance         |  1000.0  |      +ve      |
#   RatQuad.lengthscale      |     1.0  |      +ve      |
#   RatQuad.power            |     2.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/transformations.py:106: RuntimeWarning:invalid value encountered in greater
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/paramz/transformations.py:111: RuntimeWarning:invalid value encountered in greater
# ('Unexpected error:', <class 'numpy.linalg.linalg.LinAlgError'>)
# ('Failed run', 2)
# ('Optimise GPR for:', 'MAT32', 2)
#
# Name : gp
# Objective : 554494.782971
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   Mat32.variance           |   100.0  |      +ve      |
#   Mat32.lengthscale        |     1.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4544.01832383
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |               value  |  constraints  |  priors
#   Mat32.variance           |       1284948.31291  |      +ve      |
#   Mat32.lengthscale        |   0.000200145462642  |      +ve      |
#   Gaussian_noise.variance  |  5.56268464627e-309  |      +ve      |
# ('Optimise GPR for:', 'QPER', 2)
#
# Name : gp
# Objective : 97189.3190876
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |   value  |  constraints  |  priors
#   mul.rbf.variance              |    50.0  |      +ve      |
#   mul.rbf.lengthscale           |    20.0  |      +ve      |
#   mul.std_periodic.variance     |    50.0  |      +ve      |
#   mul.std_periodic.period       |  4000.0  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance       |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4501.0328741
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |               value  |  constraints  |  priors
#   mul.rbf.variance              |       1041.67062353  |      +ve      |
#   mul.rbf.lengthscale           |       18.9335106896  |      +ve      |
#   mul.std_periodic.variance     |       1040.39370357  |      +ve      |
#   mul.std_periodic.period       |       3999.97433523  |      +ve      |
#   mul.std_periodic.lengthscale  |   5.53428808917e-48  |      +ve      |
#   Gaussian_noise.variance       |  5.56268464627e-309  |      +ve      |
# ('Optimise GPR for:', 'PER', 2)
#
# Name : gp
# Objective : 180017.770853
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14639.0468897
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     115239.934174  |      +ve      |
#   std_periodic.period       |     4000.10968593  |      +ve      |
#   std_periodic.lengthscale  |  0.00500418620429  |      +ve      |
#   Gaussian_noise.variance   |     102729.353721  |      +ve      |
# ('Optimise GPR for:', 'RBF', 3)
#
# Name : gp
# Objective : 149491.795362
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   rbf.variance             |  1000.0  |      +ve      |
#   rbf.lengthscale          |    10.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14116.2032243
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   rbf.variance             |  889530.623028  |      +ve      |
#   rbf.lengthscale          |  8.65211377225  |      +ve      |
#   Gaussian_noise.variance  |  46816.6183689  |      +ve      |
# ('Optimise GPR for:', 'RQ', 3)
#
# Name : gp
# Objective : 217210.824523
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   RatQuad.variance         |  1000.0  |      +ve      |
#   RatQuad.lengthscale      |     1.0  |      +ve      |
#   RatQuad.power            |     2.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14116.2037066
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   RatQuad.variance         |  889493.170676  |      +ve      |
#   RatQuad.lengthscale      |  2053.88689726  |      +ve      |
#   RatQuad.power            |  56354.1759376  |      +ve      |
#   Gaussian_noise.variance  |    46819.22608  |      +ve      |
# ('Optimise GPR for:', 'MAT32', 3)
#
# Name : gp
# Objective : 587795.758496
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   Mat32.variance           |   100.0  |      +ve      |
#   Mat32.lengthscale        |     1.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4249.68846236
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |               value  |  constraints  |  priors
#   Mat32.variance           |       759248.929703  |      +ve      |
#   Mat32.lengthscale        |   3.86799828111e-09  |      +ve      |
#   Gaussian_noise.variance  |  5.56268464627e-309  |      +ve      |
# ('Optimise GPR for:', 'QPER', 3)
#
# Name : gp
# Objective : 101917.543836
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |   value  |  constraints  |  priors
#   mul.rbf.variance              |    50.0  |      +ve      |
#   mul.rbf.lengthscale           |    20.0  |      +ve      |
#   mul.std_periodic.variance     |    50.0  |      +ve      |
#   mul.std_periodic.period       |  4000.0  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance       |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4115.20345041
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |              value  |  constraints  |  priors
#   mul.rbf.variance              |      1561.41510685  |      +ve      |
#   mul.rbf.lengthscale           |      15.8952181362  |      +ve      |
#   mul.std_periodic.variance     |      1561.41510684  |      +ve      |
#   mul.std_periodic.period       |      3999.99869945  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.00102683772586  |      +ve      |
#   Gaussian_noise.variance       |  6.74348127675e-30  |      +ve      |
# ('Optimise GPR for:', 'PER', 3)
#
# Name : gp
# Objective : 190451.718357
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14573.6260647
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     122593.771209  |      +ve      |
#   std_periodic.period       |     4000.11477803  |      +ve      |
#   std_periodic.lengthscale  |  0.00508375427981  |      +ve      |
#   Gaussian_noise.variance   |     94976.1410291  |      +ve      |
# ('Optimise GPR for:', 'RBF', 4)
#
# Name : gp
# Objective : 165450.513872
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   rbf.variance             |  1000.0  |      +ve      |
#   rbf.lengthscale          |    10.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14186.9275325
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   rbf.variance             |  1002141.92046  |      +ve      |
#   rbf.lengthscale          |  8.63511480074  |      +ve      |
#   Gaussian_noise.variance  |  49871.9341276  |      +ve      |
# ('Optimise GPR for:', 'RQ', 4)
#
# Name : gp
# Objective : 235185.55363
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   RatQuad.variance         |  1000.0  |      +ve      |
#   RatQuad.lengthscale      |     1.0  |      +ve      |
#   RatQuad.power            |     2.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14186.9279998
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   RatQuad.variance         |  1002081.10177  |      +ve      |
#   RatQuad.lengthscale      |  2363.67883849  |      +ve      |
#   RatQuad.power            |  74929.0562577  |      +ve      |
#   Gaussian_noise.variance  |  49871.6083426  |      +ve      |
# ('Optimise GPR for:', 'MAT32', 4)
#
# Name : gp
# Objective : 646474.252211
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   Mat32.variance           |   100.0  |      +ve      |
#   Mat32.lengthscale        |     1.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 3668.65126727
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |               value  |  constraints  |  priors
#   Mat32.variance           |       934361.551785  |      +ve      |
#   Mat32.lengthscale        |       2.82972486413  |      +ve      |
#   Gaussian_noise.variance  |  5.56268464627e-309  |      +ve      |
# ('Optimise GPR for:', 'QPER', 4)
#
# Name : gp
# Objective : 108926.893988
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |   value  |  constraints  |  priors
#   mul.rbf.variance              |    50.0  |      +ve      |
#   mul.rbf.lengthscale           |    20.0  |      +ve      |
#   mul.std_periodic.variance     |    50.0  |      +ve      |
#   mul.std_periodic.period       |  4000.0  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance       |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4451.40900148
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |               value  |  constraints  |  priors
#   mul.rbf.variance              |       1075.47456186  |      +ve      |
#   mul.rbf.lengthscale           |       45.4407099759  |      +ve      |
#   mul.std_periodic.variance     |       1068.35597655  |      +ve      |
#   mul.std_periodic.period       |       3999.98830115  |      +ve      |
#   mul.std_periodic.lengthscale  |   1.16880605606e-26  |      +ve      |
#   Gaussian_noise.variance       |  9.55000482527e-158  |      +ve      |
# ('Optimise GPR for:', 'PER', 4)
#
# Name : gp
# Objective : 205741.866684
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:113: RuntimeWarning:overflow encountered in square
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:132: RuntimeWarning:overflow encountered in square
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:134: RuntimeWarning:divide by zero encountered in divide
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:134: RuntimeWarning:invalid value encountered in multiply
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:136: RuntimeWarning:divide by zero encountered in divide
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:136: RuntimeWarning:invalid value encountered in divide
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:144: RuntimeWarning:invalid value encountered in multiply
#  /home/riddhisw/anaconda2/lib/python2.7/site-packages/GPy/kern/src/standard_periodic.py:149: RuntimeWarning:invalid value encountered in multiply
# Optimisation complete!
#
# Name : gp
# Objective : 14681.0916989
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    107389.356312  |      +ve      |
#   std_periodic.period       |     4000.1268833  |      +ve      |
#   std_periodic.lengthscale  |  0.0049241028822  |      +ve      |
#   Gaussian_noise.variance   |     80739.891229  |      +ve      |
# ('Optimise GPR for:', 'RBF', 5)
#
# Name : gp
# Objective : 158656.86687
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   rbf.variance             |  1000.0  |      +ve      |
#   rbf.lengthscale          |    10.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14254.8221015
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   rbf.variance             |  932984.025878  |      +ve      |
#   rbf.lengthscale          |  8.76838817914  |      +ve      |
#   Gaussian_noise.variance  |  54803.6645569  |      +ve      |
# ('Optimise GPR for:', 'RQ', 5)
#
# Name : gp
# Objective : 228338.835584
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   RatQuad.variance         |  1000.0  |      +ve      |
#   RatQuad.lengthscale      |     1.0  |      +ve      |
#   RatQuad.power            |     2.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14254.846411
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   RatQuad.variance         |  931358.731555  |      +ve      |
#   RatQuad.lengthscale      |  431.566526757  |      +ve      |
#   RatQuad.power            |  2424.14053521  |      +ve      |
#   Gaussian_noise.variance  |  54808.9494193  |      +ve      |
# ('Optimise GPR for:', 'MAT32', 5)
#
# Name : gp
# Objective : 633155.024524
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   Mat32.variance           |   100.0  |      +ve      |
#   Mat32.lengthscale        |     1.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 3739.32215475
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |               value  |  constraints  |  priors
#   Mat32.variance           |       923648.843466  |      +ve      |
#   Mat32.lengthscale        |       2.73516892837  |      +ve      |
#   Gaussian_noise.variance  |  2.51050304304e-106  |      +ve      |
# ('Optimise GPR for:', 'QPER', 5)
#
# Name : gp
# Objective : 105560.490512
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |   value  |  constraints  |  priors
#   mul.rbf.variance              |    50.0  |      +ve      |
#   mul.rbf.lengthscale           |    20.0  |      +ve      |
#   mul.std_periodic.variance     |    50.0  |      +ve      |
#   mul.std_periodic.period       |  4000.0  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance       |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4566.049865
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |              value  |  constraints  |  priors
#   mul.rbf.variance              |      1212.31172072  |      +ve      |
#   mul.rbf.lengthscale           |      21.7386048991  |      +ve      |
#   mul.std_periodic.variance     |      1212.31203923  |      +ve      |
#   mul.std_periodic.period       |      3999.98189375  |      +ve      |
#   mul.std_periodic.lengthscale  |  6.27487220492e-35  |      +ve      |
#   Gaussian_noise.variance       |  1.00922890078e-50  |      +ve      |
# ('Optimise GPR for:', 'PER', 5)
#
# Name : gp
# Objective : 198628.682421
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14694.6797818
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     124327.369897  |      +ve      |
#   std_periodic.period       |     4000.09149672  |      +ve      |
#   std_periodic.lengthscale  |  0.00507606818238  |      +ve      |
#   Gaussian_noise.variance   |     108580.401638  |      +ve      |
# ('Optimise GPR for:', 'RBF', 6)
#
# Name : gp
# Objective : 145560.217932
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   rbf.variance             |  1000.0  |      +ve      |
#   rbf.lengthscale          |    10.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14229.6938273
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   rbf.variance             |  686803.586682  |      +ve      |
#   rbf.lengthscale          |  7.78904425781  |      +ve      |
#   Gaussian_noise.variance  |   52958.974093  |      +ve      |
# ('Optimise GPR for:', 'RQ', 6)
#
# Name : gp
# Objective : 205310.454132
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   RatQuad.variance         |  1000.0  |      +ve      |
#   RatQuad.lengthscale      |     1.0  |      +ve      |
#   RatQuad.power            |     2.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14229.6931612
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   RatQuad.variance         |   686828.58719  |      +ve      |
#   RatQuad.lengthscale      |  1838.68363608  |      +ve      |
#   RatQuad.power            |  55724.1961793  |      +ve      |
#   Gaussian_noise.variance  |  52958.7107425  |      +ve      |
# ('Optimise GPR for:', 'MAT32', 6)
#
# Name : gp
# Objective : 566089.744781
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   Mat32.variance           |   100.0  |      +ve      |
#   Mat32.lengthscale        |     1.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14228.2367868
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   Mat32.variance           |  279026.899382  |      +ve      |
#   Mat32.lengthscale        |  6.60932657221  |      +ve      |
#   Gaussian_noise.variance  |  46628.3438077  |      +ve      |
# ('Optimise GPR for:', 'QPER', 6)
#
# Name : gp
# Objective : 96538.7081901
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |   value  |  constraints  |  priors
#   mul.rbf.variance              |    50.0  |      +ve      |
#   mul.rbf.lengthscale           |    20.0  |      +ve      |
#   mul.std_periodic.variance     |    50.0  |      +ve      |
#   mul.std_periodic.period       |  4000.0  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance       |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 3899.5343694
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |               value  |  constraints  |  priors
#   mul.rbf.variance              |       757.014672709  |      +ve      |
#   mul.rbf.lengthscale           |       19.5558694609  |      +ve      |
#   mul.std_periodic.variance     |       757.014672552  |      +ve      |
#   mul.std_periodic.period       |       3999.99767259  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.000875728762904  |      +ve      |
#   Gaussian_noise.variance       |  5.56268464627e-309  |      +ve      |
# ('Optimise GPR for:', 'PER', 6)
#
# Name : gp
# Objective : 179336.740415
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14646.4193944
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     112094.550766  |      +ve      |
#   std_periodic.period       |     4000.02084552  |      +ve      |
#   std_periodic.lengthscale  |  0.00503357119308  |      +ve      |
#   Gaussian_noise.variance   |     104025.840551  |      +ve      |
# ('Optimise GPR for:', 'RBF', 7)
#
# Name : gp
# Objective : 176456.900476
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   rbf.variance             |  1000.0  |      +ve      |
#   rbf.lengthscale          |    10.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14708.3930221
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   rbf.variance             |  110799.909189  |      +ve      |
#   rbf.lengthscale          |  5.97721783221  |      +ve      |
#   Gaussian_noise.variance  |  84788.7883743  |      +ve      |
# ('Optimise GPR for:', 'RQ', 7)
#
# Name : gp
# Objective : 237409.239887
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   RatQuad.variance         |  1000.0  |      +ve      |
#   RatQuad.lengthscale      |     1.0  |      +ve      |
#   RatQuad.power            |     2.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14668.1243234
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   RatQuad.variance         |  140266.348976  |      +ve      |
#   RatQuad.lengthscale      |  272.138186247  |      +ve      |
#   RatQuad.power            |  2091.81223529  |      +ve      |
#   Gaussian_noise.variance  |   102915.68611  |      +ve      |
# ('Optimise GPR for:', 'MAT32', 7)
#
# Name : gp
# Objective : 660761.031568
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   Mat32.variance           |   100.0  |      +ve      |
#   Mat32.lengthscale        |     1.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4316.62036168
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |               value  |  constraints  |  priors
#   Mat32.variance           |       853798.045459  |      +ve      |
#   Mat32.lengthscale        |   4.91352494238e-05  |      +ve      |
#   Gaussian_noise.variance  |  5.56268464627e-309  |      +ve      |
# ('Optimise GPR for:', 'QPER', 7)
#
# Name : gp
# Objective : 109298.521595
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |   value  |  constraints  |  priors
#   mul.rbf.variance              |    50.0  |      +ve      |
#   mul.rbf.lengthscale           |    20.0  |      +ve      |
#   mul.std_periodic.variance     |    50.0  |      +ve      |
#   mul.std_periodic.period       |  4000.0  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance       |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4311.5877475
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |              value  |  constraints  |  priors
#   mul.rbf.variance              |      910.911156443  |      +ve      |
#   mul.rbf.lengthscale           |      28.8488933028  |      +ve      |
#   mul.std_periodic.variance     |      919.854433379  |      +ve      |
#   mul.std_periodic.period       |      3999.99805092  |      +ve      |
#   mul.std_periodic.lengthscale  |  4.98982912382e-08  |      +ve      |
#   Gaussian_noise.variance       |  1.43683744394e-31  |      +ve      |
# ('Optimise GPR for:', 'PER', 7)
#
# Name : gp
# Objective : 205958.877634
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14684.5595175
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     137145.011821  |      +ve      |
#   std_periodic.period       |     4000.10901158  |      +ve      |
#   std_periodic.lengthscale  |  0.00476026922016  |      +ve      |
#   Gaussian_noise.variance   |     104964.703546  |      +ve      |
# ('Optimise GPR for:', 'RBF', 8)
#
# Name : gp
# Objective : 144249.247258
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   rbf.variance             |  1000.0  |      +ve      |
#   rbf.lengthscale          |    10.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14156.6000401
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   rbf.variance             |  923672.053109  |      +ve      |
#   rbf.lengthscale          |  9.14044797535  |      +ve      |
#   Gaussian_noise.variance  |  50056.6841844  |      +ve      |
# ('Optimise GPR for:', 'RQ', 8)
#
# Name : gp
# Objective : 192603.062717
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   RatQuad.variance         |  1000.0  |      +ve      |
#   RatQuad.lengthscale      |     1.0  |      +ve      |
#   RatQuad.power            |     2.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14156.6013676
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   RatQuad.variance         |  924017.627206  |      +ve      |
#   RatQuad.lengthscale      |   2222.1513498  |      +ve      |
#   RatQuad.power            |  59094.2041341  |      +ve      |
#   Gaussian_noise.variance  |  50047.4609445  |      +ve      |
# ('Optimise GPR for:', 'MAT32', 8)
#
# Name : gp
# Objective : 509365.565578
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   Mat32.variance           |   100.0  |      +ve      |
#   Mat32.lengthscale        |     1.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4491.68157446
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |               value  |  constraints  |  priors
#   Mat32.variance           |       669836.912346  |      +ve      |
#   Mat32.lengthscale        |    6.2594881748e-08  |      +ve      |
#   Gaussian_noise.variance  |  5.56268464627e-309  |      +ve      |
# ('Optimise GPR for:', 'QPER', 8)
#
# Name : gp
# Objective : 93253.732908
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |   value  |  constraints  |  priors
#   mul.rbf.variance              |    50.0  |      +ve      |
#   mul.rbf.lengthscale           |    20.0  |      +ve      |
#   mul.std_periodic.variance     |    50.0  |      +ve      |
#   mul.std_periodic.period       |  4000.0  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance       |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4490.14059688
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |               value  |  constraints  |  priors
#   mul.rbf.variance              |       782.006598044  |      +ve      |
#   mul.rbf.lengthscale           |       19.2534708792  |      +ve      |
#   mul.std_periodic.variance     |       889.004615699  |      +ve      |
#   mul.std_periodic.period       |       3999.98887579  |      +ve      |
#   mul.std_periodic.lengthscale  |   7.91969334257e-23  |      +ve      |
#   Gaussian_noise.variance       |  7.05520729285e-214  |      +ve      |
# ('Optimise GPR for:', 'PER', 8)
#
# Name : gp
# Objective : 170574.369811
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14156.6067819
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     923941.485369  |      +ve      |
#   std_periodic.period       |     3596.61504965  |      +ve      |
#   std_periodic.lengthscale  |  0.00798452665834  |      +ve      |
#   Gaussian_noise.variance   |     50046.4193368  |      +ve      |
# ('Optimise GPR for:', 'RBF', 9)
#
# Name : gp
# Objective : 130771.584268
# Number of Parameters : 3
# ...
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14158.9933608
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     1136215.77469  |      +ve      |
#   std_periodic.period       |     3938.00011219  |      +ve      |
#   std_periodic.lengthscale  |  0.00698792069755  |      +ve      |
#   Gaussian_noise.variance   |     47771.2527491  |      +ve      |
# ('Optimise GPR for:', 'RBF', 47)
#
# Name : gp
# Objective : 135582.050497
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   rbf.variance             |  1000.0  |      +ve      |
#   rbf.lengthscale          |    10.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14139.7002871
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   rbf.variance             |  554862.174087  |      +ve      |
#   rbf.lengthscale          |   7.2361389441  |      +ve      |
#   Gaussian_noise.variance  |  47740.1320055  |      +ve      |
# ('Optimise GPR for:', 'RQ', 47)
#
# Name : gp
# Objective : 177437.122121
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   RatQuad.variance         |  1000.0  |      +ve      |
#   RatQuad.lengthscale      |     1.0  |      +ve      |
#   RatQuad.power            |     2.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 23286.6747122
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   RatQuad.variance         |  8040.95401986  |      +ve      |
#   RatQuad.lengthscale      |  203.471820981  |      +ve      |
#   RatQuad.power            |  1067.64761118  |      +ve      |
#   Gaussian_noise.variance  |  7600.43252674  |      +ve      |
# ('Optimise GPR for:', 'MAT32', 47)
#
# Name : gp
# Objective : 481145.374311
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   Mat32.variance           |   100.0  |      +ve      |
#   Mat32.lengthscale        |     1.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4577.86243211
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |               value  |  constraints  |  priors
#   Mat32.variance           |       657458.463803  |      +ve      |
#   Mat32.lengthscale        |     0.0122963949412  |      +ve      |
#   Gaussian_noise.variance  |  5.56268464627e-309  |      +ve      |
# ('Optimise GPR for:', 'QPER', 47)
#
# Name : gp
# Objective : 85675.7578919
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |   value  |  constraints  |  priors
#   mul.rbf.variance              |    50.0  |      +ve      |
#   mul.rbf.lengthscale           |    20.0  |      +ve      |
#   mul.std_periodic.variance     |    50.0  |      +ve      |
#   mul.std_periodic.period       |  4000.0  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance       |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4574.71628307
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |               value  |  constraints  |  priors
#   mul.rbf.variance              |       780.197708296  |      +ve      |
#   mul.rbf.lengthscale           |       19.3093808348  |      +ve      |
#   mul.std_periodic.variance     |       802.981182409  |      +ve      |
#   mul.std_periodic.period       |       3999.99051028  |      +ve      |
#   mul.std_periodic.lengthscale  |   5.92279348163e-20  |      +ve      |
#   Gaussian_noise.variance       |  1.41635592282e-170  |      +ve      |
# ('Optimise GPR for:', 'PER', 47)
#
# Name : gp
# Objective : 156614.837173
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14542.9378161
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     97779.2387891  |      +ve      |
#   std_periodic.period       |     4000.03334233  |      +ve      |
#   std_periodic.lengthscale  |  0.00482986647493  |      +ve      |
#   Gaussian_noise.variance   |     93491.7777244  |      +ve      |
# ('Optimise GPR for:', 'RBF', 48)
#
# Name : gp
# Objective : 160142.989892
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   rbf.variance             |  1000.0  |      +ve      |
#   rbf.lengthscale          |    10.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14675.9103436
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   rbf.variance             |  128582.313942  |      +ve      |
#   rbf.lengthscale          |   6.4551403753  |      +ve      |
#   Gaussian_noise.variance  |  105911.103773  |      +ve      |
# ('Optimise GPR for:', 'RQ', 48)
#
# Name : gp
# Objective : 229508.755481
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   RatQuad.variance         |  1000.0  |      +ve      |
#   RatQuad.lengthscale      |     1.0  |      +ve      |
#   RatQuad.power            |     2.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 16293.76607
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   RatQuad.variance         |   36965.144395  |      +ve      |
#   RatQuad.lengthscale      |  46.3577832634  |      +ve      |
#   RatQuad.power            |  198.879201443  |      +ve      |
#   Gaussian_noise.variance  |  31108.9238943  |      +ve      |
# ('Optimise GPR for:', 'MAT32', 48)
#
# Name : gp
# Objective : 637106.744856
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   Mat32.variance           |   100.0  |      +ve      |
#   Mat32.lengthscale        |     1.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 3645.51813772
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |              value  |  constraints  |  priors
#   Mat32.variance           |      578596.557631  |      +ve      |
#   Mat32.lengthscale        |       2.3182837851  |      +ve      |
#   Gaussian_noise.variance  |  1.61514731238e-21  |      +ve      |
# ('Optimise GPR for:', 'QPER', 48)
#
# Name : gp
# Objective : 106990.371125
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |   value  |  constraints  |  priors
#   mul.rbf.variance              |    50.0  |      +ve      |
#   mul.rbf.lengthscale           |    20.0  |      +ve      |
#   mul.std_periodic.variance     |    50.0  |      +ve      |
#   mul.std_periodic.period       |  4000.0  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance       |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4488.32874143
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |               value  |  constraints  |  priors
#   mul.rbf.variance              |       1251.63554512  |      +ve      |
#   mul.rbf.lengthscale           |       18.0081882373  |      +ve      |
#   mul.std_periodic.variance     |       1275.72324646  |      +ve      |
#   mul.std_periodic.period       |       3999.99681077  |      +ve      |
#   mul.std_periodic.lengthscale  |   1.35724163166e-08  |      +ve      |
#   Gaussian_noise.variance       |  2.60095554754e-234  |      +ve      |
# ('Optimise GPR for:', 'PER', 48)
#
# Name : gp
# Objective : 200842.641456
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14675.8951301
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |             value  |  constraints  |  priors
#   std_periodic.variance     |     128579.691663  |      +ve      |
#   std_periodic.period       |     4000.13741719  |      +ve      |
#   std_periodic.lengthscale  |  0.00506969198784  |      +ve      |
#   Gaussian_noise.variance   |      105903.98059  |      +ve      |
# ('Optimise GPR for:', 'RBF', 49)
#
# Name : gp
# Objective : 198257.40583
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   rbf.variance             |  1000.0  |      +ve      |
#   rbf.lengthscale          |    10.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14209.5177484
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   rbf.variance             |  1225898.87985  |      +ve      |
#   rbf.lengthscale          |  8.50443911701  |      +ve      |
#   Gaussian_noise.variance  |  49341.3635475  |      +ve      |
# ('Optimise GPR for:', 'RQ', 49)
#
# Name : gp
# Objective : 263231.82439
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   RatQuad.variance         |  1000.0  |      +ve      |
#   RatQuad.lengthscale      |     1.0  |      +ve      |
#   RatQuad.power            |     2.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 15216.8649285
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |          value  |  constraints  |  priors
#   RatQuad.variance         |   64880.046273  |      +ve      |
#   RatQuad.lengthscale      |  477.389013032  |      +ve      |
#   RatQuad.power            |  6703.41947658  |      +ve      |
#   Gaussian_noise.variance  |  44699.2601987  |      +ve      |
# ('Optimise GPR for:', 'MAT32', 49)
#
# Name : gp
# Objective : 722221.357026
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |   value  |  constraints  |  priors
#   Mat32.variance           |   100.0  |      +ve      |
#   Mat32.lengthscale        |     1.0  |      +ve      |
#   Gaussian_noise.variance  |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4633.94356944
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   gp.                      |               value  |  constraints  |  priors
#   Mat32.variance           |       1469836.63989  |      +ve      |
#   Mat32.lengthscale        |   0.000104257373987  |      +ve      |
#   Gaussian_noise.variance  |  5.56268464627e-309  |      +ve      |
# ('Optimise GPR for:', 'QPER', 49)
#
# Name : gp
# Objective : 119641.171904
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |   value  |  constraints  |  priors
#   mul.rbf.variance              |    50.0  |      +ve      |
#   mul.rbf.lengthscale           |    20.0  |      +ve      |
#   mul.std_periodic.variance     |    50.0  |      +ve      |
#   mul.std_periodic.period       |  4000.0  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance       |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 4336.67076523
# Number of Parameters : 6
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   gp.                           |              value  |  constraints  |  priors
#   mul.rbf.variance              |      1540.70112789  |      +ve      |
#   mul.rbf.lengthscale           |      16.2786665608  |      +ve      |
#   mul.std_periodic.variance     |      1540.70112688  |      +ve      |
#   mul.std_periodic.period       |      3999.99849818  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.00101039100317  |      +ve      |
#   Gaussian_noise.variance       |  2.60169252504e-13  |      +ve      |
# ('Optimise GPR for:', 'PER', 49)
#
# Name : gp
# Objective : 227916.483296
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |   value  |  constraints  |  priors
#   std_periodic.variance     |  1000.0  |      +ve      |
#   std_periodic.period       |  4000.0  |      +ve      |
#   std_periodic.lengthscale  |   0.001  |      +ve      |
#   Gaussian_noise.variance   |  1000.0  |      +ve      |
# Optimisation complete!
#
# Name : gp
# Objective : 14695.9419227
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                       |            value  |  constraints  |  priors
#   std_periodic.variance     |    157107.830704  |      +ve      |
#   std_periodic.period       |    4000.19440586  |      +ve      |
#   std_periodic.lengthscale  |  0.0047368726275  |      +ve      |
#   Gaussian_noise.variance   |    104243.409984  |      +ve      |

# %%
opt_params
# Out:
# []

# %%
pred_list.shape
# Out:
# (5, 50, 150)

# %%
fs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ba9abb932e92> in <module>()
# ----> 1 fs
#
# NameError: name 'fs' is not defined
